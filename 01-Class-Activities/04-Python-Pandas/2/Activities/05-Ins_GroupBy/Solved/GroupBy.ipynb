# %%
# Import Dependencies
import pandas as pd

# %%
# Create a reference the CSV file desired
csv_path = "Resources/ufoSightings.csv"

# Read the CSV into a Pandas DataFrame
ufo_df = pd.read_csv(csv_path)

# Print the first five rows of data to the screen
ufo_df.head()
# Out:
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                `20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
#                                             comments date posted    latitude  \
# 0  This event took place in early fall around 194...   4/27/2004  29.8830556
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005    29.38421
# 2  Green/Orange circular disc over Chester&#44 En...   1/21/2008        53.2
# 3  My older brother and twin sister were leaving ...   1/17/2004  28.9783333
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...   1/22/2004  21.4180556
#
#    longitude
# 0  -97.941111
# 1  -98.581082
# 2   -2.916667
# 3  -96.645833
# 4 -157.803611

# %%
clean_ufo_df.sort_values(['duration (seconds)','state']).head(30)
# Out:
#                datetime                                               city  \
# 4081    10/23/2008 4:45                                             remote
# 42378   5/15/1987 23:00                                        island lake
# 56596   7/15/1974 22:00                                         bridgeview
# 23754   12/9/1999 18:15                                               lyle
# 52996    6/30/2002 3:15                                 helsinki (finland)
# 13375   11/28/2001 3:41                                          milwaukie
# 18735  12/17/2011 18:40                                         springhill
# 21258  12/29/2012 19:30                                           asheboro
# 7378    10/9/2012 23:30                                         woodbourne
# 42057   5/13/2003 22:00                                              grove
# 2038   10/15/2001 20:22                                       port orchard
# 13366   11/28/2000 2:14                                             eugene
# 7262    10/9/2005 20:08                                          vancouver
# 1659   10/14/2011 21:20                                           holbrook
# 18891  12/18/2012 13:00                           atascadero (101 freeway)
# 7920   11/11/2001 19:00                                             mogote
# 32487   3/20/1999 16:00                                              macon
# 18958  12/19/2003 14:30                                        hot springs
# 13651  11/29/2004 22:15                                             irvine
# 45946    5/6/2009 21:36                                        federal way
# 60309   7/28/1997 13:00                                washington&#44 d.c.
# 32772    3/21/2012 5:00                                            phoenix
# 35330    3/8/2005 20:00                                        idaho falls
# 28605   2/25/2013 22:30                                          frostburg
# 20977  12/28/2000 12:15                                      murphreesboro
# 53001   6/30/2002 17:44                               ipswich (uk/england)
# 33248   3/23/2014 10:00                                            bemidji
# 58053   7/19/2005 22:00  tempesque bridge (west of palma approach to) (...
# 35038    3/6/2010 23:30                                       cape neddick
# 6493    10/5/2005 22:00                                              salem
#
#       state country      shape duration (seconds) duration (hours/min)  \
# 4081     wy     NaN      flash              0.001             0.001sec
# 42378    il      us      light               0.01         milliseconds
# 56596    il      us   triangle               0.01         milliseconds
# 23754    wa      us   fireball               0.01          millisecond
# 52996   NaN     NaN    unknown               0.01              0.01sec
# 13375    or      us   fireball               0.02             0.02 sec
# 18735    fl     NaN      flash               0.05           .05 second
# 21258    nc      us      light               0.05          .05 seconds
# 7378     ny      us      other               0.05          .05 seconds
# 42057    oh     NaN    unknown               0.05              .05 sec
# 2038     wa      us     circle               0.05          .05 seconds
# 13366    or      us     circle               0.08             .08 sec.
# 7262     wa      us      light               0.08         ~.08 seconds
# 1659     az      us      other                0.1          .10 seconds
# 18891    ca      us     circle                0.1          0.1 seconds
# 7920     co      us        NaN                0.1              .10 sec
# 32487    ga      us        egg                0.1            .1 second
# 18958    ar      us      other                0.2          :00.20 sec.
# 13651    ca      us    unknown                0.2               .2 sec
# 45946    wa      us        NaN                0.2               200 ms
# 60309    dc     NaN      other               0.23             .23 secs
# 32772    az      us    unknown                0.3              .30 sec
# 35330    id      us   fireball                0.3           0.3 second
# 28605    md      us    chevron                0.3          .30 seconds
# 20977    tn     NaN      flash                0.3          .30 seconds
# 53001   NaN      gb  rectangle                0.3              0.3 sec
# 33248    mn      us       disk               0.33          0.33 second
# 58053   NaN     NaN      other               0.38           .38 second
# 35038    me      us     circle                0.4               .4 sec
# 6493     or      us    chevron                0.4          .40 seconds
#
#                                                 comments date posted  \
# 4081   brilliant strobe light at 4am&#44 moving light...   1/10/2009
# 42378                             4 red laser like lines   1/12/2012
# 56596  Triangular streak SW to NE horizon to horizon ...   1/17/2004
# 23754  Incredible...full moon sized bright orange fir...  12/16/1999
# 52996                                    Overpassing UFO    7/1/2002
# 13375  High speed moving fireball fallow by a bright ...   12/5/2001
# 18735  We saw a flash of light while observing a plan...   1/12/2012
# 21258  Single bluish white downward arc of fast movin...    2/4/2013
# 7378   A basket -shaped object&#44 intense orange at ...  10/30/2012
# 42057                                bright flaring star   5/27/2003
# 2038   Large blue circular object observed falling at...  11/20/2001
# 13366  Brilliant White light seen traveling N to S al...   12/2/2000
# 7262   Yellowish&#44 orange object travelling much fa...  10/11/2005
# 1659   This fast moving craft was low flying and not ...  12/12/2011
# 18891  Blue almost electrical circle of blue light  c...  12/20/2012
# 7920   When returing from hunting elk seen a green bl...  11/20/2001
# 32487  While videoing trees and sides of house object...   9/28/2002
# 18958  THE OBJECT WAS LONG LIKE A AIRPLAIN &#44 BUT H...   1/17/2004
# 13651  the object emitted sparks from the side and re...  12/14/2004
# 45946  Pinkish white light moved *VERY RAPIDLY* acros...   5/12/2009
# 60309  While on vacation in Washington&#44 DC&#44 sta...    9/6/2002
# 32772  This maybe nothing but I had to write in. I wa...   5/13/2012
# 35330  It was not a UFO.  It appeared in the southern...   5/11/2005
# 28605  5 lights in V formation.  Slow rate of speed a...    6/2/2013
# 20977                 Shiny speck of metal or something.    1/3/2001
# 53001      Dark grey streak rapidly moving across scene.   11/4/2002
# 33248  Saucer-shaped UFO caught on video in the weste...    4/4/2014
# 58053  streak of light/object moved across the sky at...    9/2/2005
# 35038    Ocean-bound low-flying saucer glimpsed in Maine   4/13/2010
# 6493   There was a lone craft in the sky&#44that seem...  10/20/2005
#
#          latitude  longitude
# 4081   -46.163992  169.875050
# 42378  42.2761111  -88.191944
# 56596       41.75  -87.804167
# 23754  45.6961111 -121.285000
# 52996   60.173324   24.941025
# 13375  45.4463889 -122.638056
# 18735   28.483168  -82.536987
# 21258  35.7077778  -79.813889
# 7378   41.7597222  -74.594444
# 42057   41.158607  -81.226990
# 2038   47.5405556 -122.635000
# 13366  44.0522222 -123.085556
# 7262   45.6388889 -122.660278
# 1659   34.9022222 -110.157500
# 18891  35.4894444 -120.669722
# 7920   37.0594444 -106.091667
# 32487  32.8405556  -83.632500
# 18958  34.5036111  -93.055000
# 13651  33.6694444 -117.822222
# 45946     47.3225 -122.311389
# 60309   38.907231  -77.036464
# 32772  33.4483333 -112.073333
# 35330  43.4666667 -112.033333
# 28605  39.6580556  -78.928611
# 20977   35.845621  -86.390270
# 53001   52.083333    1.166667
# 33248  47.4736111  -94.880000
# 58053    9.920987  -84.098549
# 35038  43.1936111  -70.621389
# 6493   44.9430556 -123.033889

# %%
# Remove the rows with missing data
clean_ufo_df = ufo_df.dropna(how="all")
clean_ufo_df.count()
# Out:
# datetime                80332
# city                    80332
# state                   74535
# country                 70662
# shape                   78400
# duration (seconds)      80332
# duration (hours/min)    80332
# comments                80317
# date posted             80332
# latitude                80332
# longitude               80332
# dtype: int64

# %%
clean_ufo_df.head()
clean_ufo_df.dtypes
# Out:
# datetime                 object
# city                     object
# state                    object
# country                  object
# shape                    object
# duration (seconds)       object
# duration (hours/min)     object
# comments                 object
# date posted              object
# latitude                 object
# longitude               float64
# dtype: object

# %%
clean_ufo_df['duration (seconds)'] = clean_ufo_df['duration (seconds)'].str.replace('`','')

# %%
# Converting the "duration (seconds)" column's values to numeric
converted_ufo_df = clean_ufo_df.copy()
converted_ufo_df["duration (seconds)"] = converted_ufo_df.loc[:,"duration (seconds)"].astype(float)

# %%
converted_ufo_df.dtypes

#converted_ufo_df.head()
# Out:
# datetime                 object
# city                     object
# state                    object
# country                  object
# shape                    object
# duration (seconds)      float64
# duration (hours/min)     object
# comments                 object
# date posted              object
# latitude                 object
# longitude               float64
# dtype: object

# %%
# Filter the data so that only those sightings in the US are in a DataFrame
usa_ufo_df = converted_ufo_df.loc[converted_ufo_df["country"] == "us", :]
usa_ufo_df.head()
# Out:
#            datetime        city state country     shape  duration (seconds)  \
# 0  10/10/1949 20:30  san marcos    tx      us  cylinder              2700.0
# 3  10/10/1956 21:00        edna    tx      us    circle                20.0
# 4  10/10/1960 20:00     kaneohe    hi      us     light               900.0
# 5  10/10/1961 19:00     bristol    tn      us    sphere               300.0
# 7  10/10/1965 23:45     norwalk    ct      us      disk              1200.0
#
#   duration (hours/min)                                           comments  \
# 0           45 minutes  This event took place in early fall around 194...
# 3             1/2 hour  My older brother and twin sister were leaving ...
# 4           15 minutes  AS a Marine 1st Lt. flying an FJ4B fighter/att...
# 5            5 minutes  My father is now 89 my brother 52 the girl wit...
# 7           20 minutes  A bright orange color changing to reddish colo...
#
#   date posted    latitude  longitude
# 0   4/27/2004  29.8830556  -97.941111
# 3   1/17/2004  28.9783333  -96.645833
# 4   1/22/2004  21.4180556 -157.803611
# 5   4/27/2007      36.595  -82.188889
# 7   10/2/1999     41.1175  -73.408333

# %%
# Count how many sightings have occured within each state
 = usa_ufo_df["state_countsstate"].value_counts()
state_counts.head()
# Out:
# ca    8912
# wa    3966
# fl    3835
# tx    3447
# ny    2980
# Name: state, dtype: int64

# %%
# Using GroupBy in order to separate the data into fields according to "state" values
grouped_usa_df = usa_ufo_df.groupby(['state'])

# The object returned is a "GroupBy" object and cannot be viewed normally...
print(grouped_usa_df)

# In order to be visualized, a data function must be used...
grouped_usa_df.count().head(10)
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x0000015A475AB308>
#        datetime  city  country  shape  duration (seconds)  \
# state
# ak          319   319      319    311                 268
# al          642   642      642    629                 564
# ar          588   588      588    578                 496
# az         2414  2414     2414   2362                2017
# ca         8912  8912     8912   8684                7392
# co         1413  1413     1413   1385                1152
# ct          892   892      892    866                 715
# dc            7     7        7      7                   5
# de          166   166      166    165                 138
# fl         3835  3835     3835   3754                3350
#
#        duration (hours/min)  comments  date posted  latitude  longitude
# state
# ak                      319       319          319       319         319
# al                      642       642          642       642         642
# ar                      588       588          588       588         588
# az                     2414      2414         2414      2414        2414
# ca                     8912      8911         8912      8912        8912
# co                     1413      1413         1413      1413        1413
# ct                      892       891          892       892         892
# dc                        7         7            7         7           7
# de                      166       166          166       166         166
# fl                     3835      3835         3835      3835        3835

# %%
grouped_usa_df["duration (seconds)"].sum()
# Out:
# state
# ak      951000.00
# al      840390.00
# ar      650848.50
# az    15081472.90
# ca    27567925.47
# co     4122467.10
# ct    12464112.30
# dc         925.50
# de      118810.50
# fl     2929453.70
# ga     9336854.10
# hi     6692643.00
# ia      513936.50
# id      400609.30
# il     1827708.57
# in     4044247.70
# ks      781978.50
# ky     3234916.00
# la     6731708.00
# ma     1303291.00
# md      602119.80
# me     1678491.90
# mi     6784468.60
# mn      722355.33
# mo     1225695.50
# ms     3345134.00
# mt      988173.00
# nc     1750460.35
# nd       92009.00
# ne      274427.00
# nh      991717.00
# nj     7637736.00
# nm     3070128.59
# nv     2256357.00
# ny     8360372.25
# oh     2546152.60
# ok      730854.30
# or     1545188.77
# pa     9450553.50
# pr       26247.00
# ri      372417.50
# sc      961113.30
# sd      443549.50
# tn     1709676.30
# tx     3290004.50
# ut     3343923.50
# va     2979355.00
# vt      238139.50
# wa    55918853.14
# wi     2101089.00
# wv     2908397.00
# wy      195894.50
# Name: duration (seconds), dtype: float64

# %%
# Since "duration (seconds)" was converted to a numeric time, it can now be summed up per state
state_duration = grouped_usa_df["duration (seconds)"].sum()
state_duration.head()
# Out:
# state
# ak      951000.00
# al      840390.00
# ar      650848.50
# az    15081472.90
# ca    27567925.47
# Name: duration (seconds), dtype: float64

# %%
# Creating a new DataFrame using both duration and count
state_summary_df = pd.DataFrame({"Number of Sightings": state_counts,
                                    "Total Visit Time": state_duration})
state_summary_df.head()
# Out:
#     Number of Sightings  Total Visit Time
# ak                  319         951000.00
# al                  642         840390.00
# ar                  588         650848.50
# az                 2414       15081472.90
# ca                 8912       27567925.47

# %%
# It is also possible to group a DataFrame by multiple columns
# This returns an object with multiple indexes, however, which can be harder to deal with
grouped_international_data = converted_ufo_df.groupby(['country', 'state'])

grouped_international_data.count().head(20)
# Out:
#                datetime  city  shape  duration (seconds)  \
# country state
# au      al            1     1      1                   1
#         dc            1     1      1                   1
#         nt            2     2      2                   2
#         oh            1     1      1                   0
#         sa            2     2      2                   1
#         wa            2     2      2                   2
#         yt            1     1      1                   1
# ca      ab          288   288    284                 221
#         bc          691   691    677                 545
#         mb          127   127    124                  98
#         nb           86    86     86                  60
#         nf           15    15     15                  13
#         ns          101   101    101                  68
#         nt           13    13     13                  12
#         on         1354  1354   1335                1011
#         pe           10    10     10                   6
#         pq           64    64     62                  50
#         qc          124   124    124                  96
#         sa           27    27     27                  19
#         sk           78    78     77                  58
#
#                duration (hours/min)  comments  date posted  latitude  \
# country state
# au      al                        1         1            1         1
#         dc                        1         1            1         1
#         nt                        2         2            2         2
#         oh                        1         1            1         1
#         sa                        2         2            2         2
#         wa                        2         2            2         2
#         yt                        1         1            1         1
# ca      ab                      288       288          288       288
#         bc                      691       691          691       691
#         mb                      127       127          127       127
#         nb                       86        86           86        86
#         nf                       15        15           15        15
#         ns                      101       101          101       101
#         nt                       13        13           13        13
#         on                     1354      1354         1354      1354
#         pe                       10        10           10        10
#         pq                       64        64           64        64
#         qc                      124       124          124       124
#         sa                       27        27           27        27
#         sk                       78        78           78        78
#
#                longitude
# country state
# au      al              1
#         dc              1
#         nt              2
#         oh              1
#         sa              2
#         wa              2
#         yt              1
# ca      ab            288
#         bc            691
#         mb            127
#         nb             86
#         nf             15
#         ns            101
#         nt             13
#         on           1354
#         pe             10
#         pq             64
#         qc            124
#         sa             27
#         sk             78

# %%
# Converting a GroupBy object into a DataFrame
international_duration_df = pd.DataFrame(
    grouped_international_data["duration (seconds)"].sum())
international_duration_df.head(30)
# Out:
#                duration (seconds)
# country state
# au      al                  900.0
#         dc                  300.0
#         nt                  360.0
#         oh                    0.0
#         sa                  300.0
#         wa                  450.0
#         yt                   30.0
# ca      ab               212131.0
#         bc               540608.8
#         mb               554161.0
#         nb                46292.0
#         nf                18610.0
#         ns                83520.0
#         nt                29070.0
#         on             83934583.2
#         pe                 3137.0
#         pq                26952.0
#         qc                98802.0
#         sa                29566.0
#         sk                72602.0
#         yk                  720.0
#         yt                 3664.0
# gb      bc                86400.0
#         la                  600.0
#         ms                  180.0
#         nc                  600.0
#         ns                    0.0
#         nt                  900.0
#         ri                    0.0
#         sk                   60.0
