# %%
# %matplotlib notebook

# %%
# Import Dependencies
import random
import matplotlib.pyplot as plt
import numpy as np

# %%
# The maximum x value for our chart will be 100
x_limit = 100

# List of values from 0 to 100 each value being 1 greater than the last
x_axis = np.arange(0, x_limit, 1)

# Create a random array of data that we will use for our y values
data = [random.random() for value in x_axis]

# %%
data
# Out:
# [0.06662950447906602,
#  0.007727560266373001,
#  0.14358817435375704,
#  0.008081169508181163,
#  0.961042390750323,
#  0.7718080496114398,
#  0.14745673932961045,
#  0.1277695516120081,
#  0.8655441516604352,
#  0.6846262415215824,
#  0.688830714840918,
#  0.14641886366619272,
#  0.6633623891372131,
#  0.3801816326010695,
#  0.09209682703592026,
#  0.17861109103754746,
#  0.5688450348299222,
#  0.9914589470020191,
#  0.6122419901151034,
#  0.3251705856521614,
#  0.32080215224688347,
#  0.4898726507741632,
#  0.7443433090672307,
#  0.5868827830655985,
#  0.15971011067638807,
#  0.12080932025711533,
#  0.6022873879967922,
#  0.39407957075536826,
#  0.8564765869168243,
#  0.3982586693320721,
#  0.9146492517257208,
#  0.9270659849709219,
#  0.03293601797333667,
#  0.21832111164987733,
#  0.2720930222483894,
#  0.1087793099232629,
#  0.5703793425712052,
#  0.9641996835419829,
#  0.14547751042679835,
#  0.7864140174029355,
#  0.26054659120166335,
#  0.5933492111148977,
#  0.06502940015299197,
#  0.4264686864852224,
#  0.43943656001040865,
#  0.5334713609976625,
#  0.7690622231266631,
#  0.9107462901918912,
#  0.5846938439608281,
#  0.7384457823769452,
#  0.540268438059616,
#  0.5570528839385273,
#  0.2535689249737634,
#  0.442382313350986,
#  0.9699641511381196,
#  0.9957931745766188,
#  0.3799195685921508,
#  0.9086471320244459,
#  0.5626107938001239,
#  0.5444398046013971,
#  0.3938633563380134,
#  0.029623357362215108,
#  0.3026365134238892,
#  0.53456958157509,
#  0.8277939716116922,
#  0.5766536024046341,
#  0.1499808120170688,
#  0.11942358903354844,
#  0.058837103044925176,
#  0.004225519883949702,
#  0.17361128340794696,
#  0.8390105591973261,
#  0.1643929302285443,
#  0.4747202282263423,
#  0.18235519363161945,
#  0.5867664337857273,
#  0.6105211649467306,
#  0.05475758886142368,
#  0.2820820525234585,
#  0.402867803270051,
#  0.23283205521007033,
#  0.1525978996652847,
#  0.7665818813377084,
#  0.40923551385450085,
#  0.181780777268298,
#  0.8364046168358645,
#  0.012279131755902783,
#  0.8349501219620153,
#  0.7275779104484001,
#  0.5598348377904588,
#  0.895680477218565,
#  0.1567665302961394,
#  0.06741564745768913,
#  0.9999997923300405,
#  0.6306531009336643,
#  0.730144760846087,
#  0.20538716186650097,
#  0.9232484356270441,
#  0.8311526714402577,
#  0.18788844305853525]

# %%
# Tells matplotlib that we want to make a scatter plot
# The size of each point on our plot is determined by their x value
plt.scatter(x_axis, data, marker="o", facecolors="red", edgecolors="black",
            s=x_axis, alpha=0.75)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# The y limits of our scatter plot is 0 to 1
plt.ylim(0, 1)
# Out:
# (0, 1)

# %%
# The x limits of our scatter plot is 0 to 100
plt.xlim(0, x_limit)
# Out:
# (0, 100)

# %%
# Prints the scatter plot to the screen
plt.show()
