# %%
# Create code to answer each of the following questions.
# Hint: You will need multiple target URLs and multiple API requests.

# Dependencies
import requests
import json
import pandas as pd

# Google API Key
from config import gkey

# %%
# 1. What are the geocoordinates (latitude and longitude) of Arlington, VA?
target_city = 'Arlington, VA'

params = {
    'address': target_city,
    'key': gkey
}

# Build URL using the Google Maps API
base_url = 'https://maps.googleapis.com/maps/api/geocode/json'

print(f'Drill #1: The Geocoordinates of {target_city}')

# Run request
response = requests.get(base_url, params=params)
#response = requests.get(f'base_url?address={target_city}&key={gkey})

# print the response URL, avoid doing for public GitHub repos in order to avoid exposing key
print(response.url)

# Convert to JSON
geo = response.json()

# Extract lat/lng
lat = geo['results'][0]['geometry']['location']['lat']
lng = geo['results'][0]['geometry']['location']['lng']

# Print results
print(f'{target_city}: {lat}, {lng}')
# Out:
# Drill #1: The Geocoordinates of Arlington, VA
# https://maps.googleapis.com/maps/api/geocode/json?address=Arlington%2C+VA&key=AIzaSyDcZTnkXUQ9YekVERlvsnzud_-R0dfi2Nw
# Arlington, VA: 38.8799697, -77.1067698

# %%
def getCoordinates(location, gkey):

    base_url = 'https://maps.googleapis.com/maps/api/geocode/json'

    params = {
    'address': location,
    'key': gkey
    }
    
    response = requests.get(base_url, params=params).json()

    lat = response['results'][0]['geometry']['location']['lat']
    lng = response['results'][0]['geometry']['location']['lng']

    latlng = (lat,lng)
    
    return latlng

# %%
getCoordinates('baltimore, md', gkey)
# Out:
# (39.2903848, -76.6121893)

# %%
getCoordinates('1600 Maryland Ave NE', gkey)
# Out:
# (38.9015874, -76.98073289999999)

# %%
# 2. What are the geocoordinates (latitude and longitude) of The White House?
# update params dict
location = 'The White House'
params = {
            'address': location,
            'key': gkey
        }

print(f'Drill #2: The Geocoordinates of {location}')

# Run request
response = requests.get(base_url, params=params)
#response = requests.get(f'{base_url}?address={location}&key={gkey}')

# print the response URL, avoid doing for public GitHub repos in order to avoid exposing key
print(response.url)

dc_geo = response.json()
# Extract lat/lng
lat = dc_geo['results'][0]['geometry']['location']['lat']
lng = dc_geo['results'][0]['geometry']['location']['lng']

# Print results
print(f'{location}: {lat}, {lng}')
# Out:
# Drill #2: The Geocoordinates of The White House
# https://maps.googleapis.com/maps/api/geocode/json?address=The+White+House&key=AIzaSyDcZTnkXUQ9YekVERlvsnzud_-R0dfi2Nw
# The White House: 38.8976763, -77.0365298

# %%
getCoordinates('The White House', gkey)
# Out:
# (38.8976763, -77.0365298)

# %%
# 3. Find the name and address of a bike shop in Baltimore.
#    Hint: See https://developers.google.com/places/web-service/supported_types

latlng = getCoordinates('baltimore, md', gkey)
print(latlng)
target_type = "bicycle_store"
coords = f"{latlng[0]},{latlng[1]}"
radius = 8000

# rewrite params dict

params = {
    "location": coords,
    "types": target_type,
    "radius": radius,
    "key": gkey
}

# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

print("Drill #3:")

# Run request
response = requests.get(base_url, params)

# print the response URL, avoid doing for public GitHub repos in order to avoid exposing key
print(response.url)

bikes = response.json()

# Print the JSON (pretty printed)
# print(json.dumps(bikes, indent=4, sort_keys=True))

# Print the name and address of the first bike shop to appear
for i in range(len(bikes)):
    print(bikes["results"][i]["name"])
    print(bikes["results"][i]["vicinity"])
    print('---')
# Out:
# (39.2903848, -76.6121893)
# Drill #3:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=39.2903848%2C-76.6121893&types=bicycle_store&radius=8000&key=AIzaSyDcZTnkXUQ9YekVERlvsnzud_-R0dfi2Nw
# Race Pace Bicycles
# 1414 Key Highway, Baltimore
# ---
# Baltimore Bicycle Works
# 1813 Falls Road, Baltimore
# ---
# HandleBar Bike Shop
# 511 South Caroline Street, Baltimore
# ---

# %%
bikes
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 39.2732113, 'lng': -76.60214239999999},
#     'viewport': {'northeast': {'lat': 39.2746803802915,
#       'lng': -76.60069491970849},
#      'southwest': {'lat': 39.2719824197085, 'lng': -76.60339288029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Race Pace Bicycles',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 850,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110899580914003898616">Race Pace Bicycles</a>'],
#      'photo_reference': 'CmRaAAAAPU1gw2QMg6md0uRMP8JLN9btPnKX4Y8B2NF654GmEUDlorei761F4mSEDvC484kMhBIEtW2l1xp2a1Y0VssBzm_wqIV6erkGdsASzjN7q5toDoMCS-calZiA_YG2h_XPEhDtstj7zX8MnboQF1HtGdQRGhQlvanA5v2djJ3Io-BVNHcloxjM4A',
#      'width': 1280}],
#    'place_id': 'ChIJewWU_nADyIkRSkn0ABCeiDs',
# ...

# %%
# 4. Find a balloon shop near the White House.

latlng = getCoordinates('The White House', gkey)

target_search = "balloon shop"
coords = f"{latlng[0]},{latlng[1]}"
radius = 1600

# redefine params
params = {
    "location": coords,
    "keyword": target_search,
    "radius": radius,
    "key": gkey
}

# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

print("Drill #4:")

# Run request
dc_balloons = requests.get(base_url, params).json()

# Print the JSON (pretty printed)
#print(json.dumps(dc_balloons, indent=4, sort_keys=True))

# Print the name and address of the first balloon shop that appears

for r in dc_balloons["results"]:
    print(r["name"])
    print(r["vicinity"])
    print('---')
# Out:
# Drill #4:
# BASHES
# DELIVERY ONLY (NO PICK UP, 1155 F St NW, Washington
# ---
# Monarch Novelty Co
# 1331 14th St NW, Washington
# ---

# %%
# 5. Find the nearest dentist to your house.
# Hint: Use Google Maps to find your latitude and Google Places to find
# the dentist. You may also need the rankby property.

my_geo = getCoordinates('1600 Maryland Ave NE', gkey)

lat = my_geo[0]
lng = my_geo[1]

# Use lat, lng to use places API to find nearest dentist
target_search = "dentist"

params = {
    "location": f"{lat},{lng}",
    "keyword": target_search,
    "rankby": "distance",
    "key": gkey
}

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"


# Run request
response = requests.get(base_url, params)

# print the response URL, avoid doing for public GitHub repos in order to avoid exposing key
# print(response.url)
my_dentist = response.json()

# Print the JSON (pretty printed)
# print(json.dumps(my_dentist, indent=4, sort_keys=True))

# Print the name and address of the first dentist that appears
print(my_dentist["results"][0]["name"])
print(my_dentist["results"][0]["vicinity"])


for r in my_dentist["results"]:
    print(r["name"])
    print(r["vicinity"])
    print('---')
# Out:
# Kool Smiles Dentist
# 1531 Maryland Ave NE, Washington
# Kool Smiles Dentist
# 1531 Maryland Ave NE, Washington
# ---
# Lyons Brenda M DDS
# 1531 Maryland Ave NE, Washington
# ---
# Tran Tu DDS
# 1531 Maryland Ave NE, Washington
# ---
# DC Dental Group
# 1647 Benning Rd NE #206, Washington
# ---
# Colleen Lloyd Family Dentistry
# 1647 Benning Rd NE # 204, Washington
# ---
# Rhodes Juanita E DDS
# 1647 Benning Rd NE, Washington
# ---
# Gena Bracey-Stokes, DDS
# 1647 Benning Rd NE #206, Washington
# ---
# Dancil Abraham DDS
# 1800 Benning Rd NE # A, Washington
# ---
# Crawford DDS & Associates
# 1922 Benning Rd NE, Washington
# ---
# Gant Raymond C DDS
# 1922 Benning Rd NE, Washington
# ---
# Dr. Albert A. Coombs III, DMD
# 2415 Benning Rd NE, Washington
# ---
# Advance Dental Care: Dr. Bruk Taeme DDS
# 701 K St NE #101, Washington
# ---
# Coley James F DDS
# 500 8th St NE, Washington
# ---
# East Capitol Dental - Bowers Larry DDS
# 711 E Capitol St SE, Washington
# ---
# ...

# %%
# 6. Bonus: Find the names and addresses of the top five restaurants in your home city.
#    Hint: Read about "Text Search Results"
# (https://developers.google.com/places/web-service/search#TextSearchRequests)
my_phrase = "restaurant"
target_url = "https://maps.googleapis.com/maps/api/place/textsearch/json"

params = {
    "query": my_phrase,
    "key": gkey
}

print("Drill #6: Bonus")

response = requests.get(target_url, params)

# print the response URL, avoid doing for public GitHub repos in order to avoid exposing key
print(response.url)
restaurants = response.json()
# print(json.dumps(happy_places, indent=4, sort_keys=True))

restaurants_json = restaurants['results']
# Out:
# Drill #6: Bonus
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=restaurant&key=AIzaSyDcZTnkXUQ9YekVERlvsnzud_-R0dfi2Nw

# %%
print(json.dumps(restaurants, indent=4))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "AcnaJv1l00r43aXHiSF2R2y4_yc0M25FwdpI3qALLFfnC_-DfthIzNYMrL9n0AMHw4I-F8DvxhKCpg-IJHnoA97qMabFTgPlpiOxUYJB1yaXgXjJUaLa1i_lPFz6q5u40P2zAlUbj9T-e-WgQY8q_bap1fiGTiH7rOSqr_PyIqiw6nJ2WiTyyRUQihqPBtd5CIJ8iumKeClTnkg-I7wcMn_Tx7-Row91QSJLocYHibObky8zu0TvbX1XpQ-6q7Z_wAQFwSC3AYq7Ovw8wS0DmszirdyBxeI6eZ6Jqt1VX4PV5kOXo_jIk-AM2cneDpmVvaAcTBwlLcTmg5KUjir61oL1H1jKcwlmsRH0ofhdGuWWM5Vcqp-wqVso96bgYKnJi0t1bJdqRYtQdD-kqOz9o6sJV6OKimayACIL8-SAQRMmx6QasghQVcaXaP4U8WF5XFWKsDssgEDXejDDNQyBpI9t-ZxcNguL-hZs2RmQRkQ_cm2y1GgbS568U2U1JcP1g8v_edqmBM_WGTgfw4zBKWXgmcnslac_smr1VE63eq4YtPJR9mkHHE1YgqudrZaH3rUpAvEzmHTwuGsTFwbJBPCQcpF1lvl2Iv160PZSPG8UF5Xsm3i8lX8Ksodheg-TKRDl2xxV6TqyGft5vT9j8gL9T93G2JiEmKLe8LwNtXE8tAAmuhRuhMQWoTOOH2xLj0JIZiAZbzXVRWDSiSjqlbOUqm7nwmzd_I18UJsrLa5sCcqD5zIqA3gbCVzpAfo3R2vbrbAWol9MzA_Kb_azIIa5",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
# ...

# %%
restaurants_df = pd.DataFrame(restaurants_json)
restaurants_df.head()
# Out:
#   business_status                                  formatted_address  \
# 0     OPERATIONAL  2000 Fenwick St NE, Washington, DC 20002, Unit...
# 1     OPERATIONAL  1805 Montana Ave NE B, Washington, DC 20002, U...
# 2     OPERATIONAL  1344 H St NE, Washington, DC 20002, United States
# 3     OPERATIONAL  1250 Bladensburg Rd NE, Washington, DC 20002, ...
# 4     OPERATIONAL  409 15th St NE, Washington, DC 20002, United S...
#
#                                             geometry  \
# 0  {'location': {'lat': 38.9147265, 'lng': -76.98...
# 1  {'location': {'lat': 38.9194465, 'lng': -76.97...
# 2  {'location': {'lat': 38.90036389999999, 'lng':...
# 3  {'location': {'lat': 38.9067868, 'lng': -76.97...
# 4  {'location': {'lat': 38.8951702, 'lng': -76.98...
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# ...

# %%
top_restaurants = restaurants_df.sort_values(by='rating', ascending=False)
top_restaurants.head(10)
# Out:
#        business_status                                  formatted_address  \
# 4          OPERATIONAL  409 15th St NE, Washington, DC 20002, United S...
# 0          OPERATIONAL  2000 Fenwick St NE, Washington, DC 20002, Unit...
# 12         OPERATIONAL  1301 H St NE, Washington, DC 20002, United States
# 11         OPERATIONAL  1324 H St NE, Washington, DC 20002, United States
# 10         OPERATIONAL  1250 5th St NE, Washington, DC 20002, United S...
# 2          OPERATIONAL  1344 H St NE, Washington, DC 20002, United States
# 16  CLOSED_TEMPORARILY   818 H St NE, Washington, DC 20002, United States
# 18         OPERATIONAL  1208 H St NE, Washington, DC 20002, United States
# 5          OPERATIONAL  1253 H St NE, Washington, DC 20002, United States
# 7          OPERATIONAL  1355 H St NE, Washington, DC 20002, United States
#
#                                              geometry  \
# 4   {'location': {'lat': 38.8951702, 'lng': -76.98...
# ...

# %%
top_restaurants = top_restaurants[['name','rating','price_level', 'user_ratings_total', 'business_status']]

# %%
top_restaurants.sort_values('rating', ascending=False).head(10)
# Out:
#                             name  rating  price_level  user_ratings_total  \
# 4   Manna Korean BBQ and Dosirak     5.0          NaN                  28
# 0                 Via Ghibellina     4.9          NaN                  22
# 12                  Kitchen Cray     4.7          NaN                  20
# 11                     Stable DC     4.7          2.0                 288
# 10                    St. Anselm     4.7          3.0                 742
# 2                        Sospeso     4.6          2.0                 251
# 16    Quara Ethiopian Restaurant     4.6          NaN                 143
# 18                   Smokin' Pig     4.6          NaN                  23
# 17                 Panda Gourmet     4.5          NaN                  16
# 8               Toki Underground     4.5          2.0                1188
#
#        business_status
# 4          OPERATIONAL
# 0          OPERATIONAL
# 12         OPERATIONAL
# 11         OPERATIONAL
# 10         OPERATIONAL
# ...

# %%
top_restaurants.loc[top_restaurants['rating']>=4.5]
# Out:
#                             name  rating  price_level  user_ratings_total  \
# 4   Manna Korean BBQ and Dosirak     5.0          NaN                  28
# 0                 Via Ghibellina     4.9          NaN                  22
# 12                  Kitchen Cray     4.7          NaN                  20
# 11                     Stable DC     4.7          2.0                 288
# 10                    St. Anselm     4.7          3.0                 742
# 2                        Sospeso     4.6          2.0                 251
# 16    Quara Ethiopian Restaurant     4.6          NaN                 143
# 18                   Smokin' Pig     4.6          NaN                  23
# 5                        Pow Pow     4.5          1.0                 339
# 7                Biergarten Haus     4.5          2.0                 765
# 8               Toki Underground     4.5          2.0                1188
# 17                 Panda Gourmet     4.5          NaN                  16
#
# ...
