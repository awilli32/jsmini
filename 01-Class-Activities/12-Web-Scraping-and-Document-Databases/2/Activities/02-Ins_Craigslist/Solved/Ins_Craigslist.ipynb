# %%
# Dependencies
from bs4 import BeautifulSoup
import requests

# %%
# URL of page to be scraped
url = 'https://newjersey.craigslist.org/search/sss?sort=rel&query=guitar'

# %%
# Retrieve page with the requests module
response = requests.get(url)
response.text
# Out:
# '\ufeff<!DOCTYPE html>\n<html class="no-js"><head>\n    <title>north jersey for sale &quot;guitar&quot;  - craigslist</title>\n    <script type="application/ld+json" id="ld_breadcrumb_data" >\n    {"@context":"https://schema.org","itemListElement":[{"item":{"name":"newjersey.craigslist.org","@id":"https://newjersey.craigslist.org"},"position":1,"@type":"ListItem"},{"item":{"name":"for sale","@id":"https://newjersey.craigslist.org/d/for-sale/search/sss"},"position":2,"@type":"ListItem"}],"@type":"BreadcrumbList"}\n</script>\n\n\n    <meta name="description" content="Buy and sell locally. Craigslist has listings for guitar for sale in the North Jersey area. Browse photos and search by condition, price, and more.">\n    <meta http-equiv="X-UA-Compatible" content="IE=Edge"/>\n        <link rel="canonical" href="https://newjersey.craigslist.org/d/for-sale/search/sss?query=guitar&amp;sort=rel">\n        <link rel="next" href="https://newjersey.craigslist.org/d/for-sale/search/sss?s=120&amp;query=guitar&amp;sort=rel">\n    <meta name="viewport" content="width=device-width,initial-scale=1">\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/cl.css?v=5ea548767c8f312eb8ee55e79d68d2c4">\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/search.css?v=3e729d7fcd43cfbedaa0ed6159bde66f">\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/jquery-ui-clcustom.css?v=3b05ddffb7c7f5b62066deff2dda9339">\n<link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/leaflet.css?v=d604b055c4c11b9fd29d0c071b394312">\n<link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/MarkerCluster.css?v=9bea97021e746649c6837e95dd9723e8">\n<link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps.css?v=d8743547c59d5ad31d4d7294c7e2f7f2">\n<!--[if IE]>\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps-ie.css?v=6bcbe5817e70c9a7f673ff72ba3e56e5">\n<![endif]-->\n\n    \n        <script type="text/javascript"><!--\nvar areaCountry = "US";\nvar areaID = "170";\nvar areaRegion = "NJ";\nvar catAbb = "sss";\nvar countOfTotalText = "image {count} of {total}";\nvar currencySymbol = "&#x0024;";\nvar defaultView = "grid";\nvar expiredFavIDs = null;\nvar imageConfig = {"1":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"4":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"0":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450"]},"3":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"2":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]}};\nvar lessInfoText = "less info";\nvar maptileBaseUrl = "//map{s}.craigslist.org/t09/{z}/{x}/{y}.png";\nvar maxResults = 3000;\nvar noImageText = "no image";\nvar pID = null;\nvar postalLat = null;\nvar postalLon = null;\nvar purveyorCategories = {"owner":"sso","dealer":"ssq","all":"sss"};\nvar searchDistance = null;\nvar sectionAbb = "sss";\nvar sectionBase = "sss";\nvar showInfoText = "show info";\nvar showMapTabs = 1;\nvar showingBanished = 0;\nvar showingFavorites = 0;\nvar starHint = "save this post in your favorites list";\nvar subarea = null;\nvar zoomToPosting = null;\n--></script>\n    \n</head>\n<body class="search has-map">\n    <script type="text/javascript"><!--\n    function C(k){return(document.cookie.match(\'(^|; )\'+k+\'=([^;]*)\')||0)[2]}\n    var pagetype, pagemode;\n    (function(){\n        var h = document.documentElement;\n        h.className = h.className.replace(\'no-js\', \'js\');\n        var b = document.body;\n        var bodyClassList = b.className.split(/\\s+/);;\n        pagetype = bodyClassList[0]; // dangerous assumption\n        var fmt = C(\'cl_fmt\');\n ...

# %%
# Create BeautifulSoup object; parse with 'html.parser'
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# Examine the results, then determine element that contains sought info
print(soup.prettify())
# Out:
# ﻿
# <!DOCTYPE html>
# <html class="no-js">
#  <head>
#   <title>
#    north jersey for sale "guitar"  - craigslist
#   </title>
#   <script id="ld_breadcrumb_data" type="application/ld+json">
#    {"@context":"https://schema.org","itemListElement":[{"item":{"name":"newjersey.craigslist.org","@id":"https://newjersey.craigslist.org"},"position":1,"@type":"ListItem"},{"item":{"name":"for sale","@id":"https://newjersey.craigslist.org/d/for-sale/search/sss"},"position":2,"@type":"ListItem"}],"@type":"BreadcrumbList"}
#   </script>
#   <meta content="Buy and sell locally. Craigslist has listings for guitar for sale in the North Jersey area. Browse photos and search by condition, price, and more." name="description"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible">
#    <link href="https://newjersey.craigslist.org/d/for-sale/search/sss?query=guitar&amp;sort=rel" rel="canonical"/>
#    <link href="https://newjersey.craigslist.org/d/for-sale/search/sss?s=120&amp;query=guitar&amp;sort=rel" rel="next"/>
#    <meta content="width=device-width,initial-scale=1" name="viewport"/>
#    <link href="//www.craigslist.org/styles/cl.css?v=5ea548767c8f312eb8ee55e79d68d2c4" media="all" rel="stylesheet" type="text/css"/>
#    <link href="//www.craigslist.org/styles/search.css?v=3e729d7fcd43cfbedaa0ed6159bde66f" media="all" rel="stylesheet" type="text/css"/>
#    <link href="//www.craigslist.org/styles/jquery-ui-clcustom.css?v=3b05ddffb7c7f5b62066deff2dda9339" media="all" rel="stylesheet" type="text/css"/>
#    <link href="//www.craigslist.org/styles/leaflet.css?v=d604b055c4c11b9fd29d0c071b394312" media="all" rel="stylesheet" type="text/css"/>
#    <link href="//www.craigslist.org/styles/MarkerCluster.css?v=9bea97021e746649c6837e95dd9723e8" media="all" rel="stylesheet" type="text/css"/>
#    <link href="//www.craigslist.org/styles/tocsmaps.css?v=d8743547c59d5ad31d4d7294c7e2f7f2" media="all" rel="stylesheet" type="text/css"/>
#    <!--[if IE]>
#     <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps-ie.css?v=6bcbe5817e70c9a7f673ff72ba3e56e5">
# <![endif]-->
#    <script type="text/javascript">
#     <!--
# var areaCountry = "US";
# var areaID = "170";
# var areaRegion = "NJ";
# var catAbb = "sss";
# var countOfTotalText = "image {count} of {total}";
# var currencySymbol = "&#x0024;";
# var defaultView = "grid";
# var expiredFavIDs = null;
# var imageConfig = {"1":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"4":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"0":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450"]},"3":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"2":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]}};
# var lessInfoText = "less info";
# var maptileBaseUrl = "//map{s}.craigslist.org/t09/{z}/{x}/{y}.png";
# var maxResults = 3000;
# var noImageText = "no image";
# var pID = null;
# var postalLat = null;
# var postalLon = null;
# var purveyorCategories = {"owner":"sso","dealer":"ssq","all":"sss"};
# var searchDistance = null;
# var sectionAbb = "sss";
# var sectionBase = "sss";
# var showInfoText = "show info";
# var showMapTabs = 1;
# var showingBanished = 0;
# var showingFavorites = 0;
# var starHint = "save this post in your favorites list";
# var subarea = null;
# var zoomToPosting = null;
# -->
#    </script>
#   </meta>
#  </head>
#  <body class="search has-map">
#   <script type="text/javascript">
#    <!--
#     function C(k){return(document.cookie.match('(^|; )'+k+'=([^;]*)')||0)[2]}
#     var pagetype, pagemode;
#     (function(){
#         var h = document.documentElement;
#         h.className = h.className.replace('no-js', 'js');
#         var b = document.body;
#         var bodyClassList = b.className.split(/\s+/);;
#         pagetype = bodyClassList[0]; // dangerous assumption
#         var fmt = C('cl_fmt');
#         if ( fmt === 'regular' || fmt === 'mobile' ) {
#             pagemode = fmt;
#         } else if (screen.width <= 480) {
#             pagemode = 'mobile';
#         } else {
#             pagemode = 'regular';
#         }
#         pagemode = pagemode === 'mobile' ? 'mobile' : 'desktop';
#         bodyClassList.push(pagemode);
#         if (C('hidesearch') === '1' && pagemode !== 'mobile') {
#             bodyClassList.push('hide-search');
#         }
#         var width = window.innerWidth || document.documentElement.clientWidth;
#         if (width > 1000) { bodyClassList.push('w1024'); }
#         if (typeof window.sectionBase !== 'undefined') {
#             var mode = (decodeURIComponent(C('cl_tocmode') || '').match(new RegExp(window.sectionBase + ':([^,]+)', 'i')) || {})[1] || window.defaultView;
#             if (mode) {
#                 bodyClassList.push(mode);
#             }
#         }
#         b.className = bodyClassList.join(' ');
#     }());
# -->
#   </script>
#   <section class="page-container" id="page-top">
#    <div class="bglogo">
#    </div>
#    <div class="tryapp">
#     try the craigslist app »
#     <a class="appstorebtn" href="https://play.google.com/store/apps/details?id=org.craigslist.CraigslistMobile">
#      Android
#     </a>
#     <a class="appstorebtn" href="https://apps.apple.com/us/app/craigslist/id1336642410">
#      iOS
#     </a>
#    </div>
#    <header class="global-header wide">
#     <a class="header-logo" href="/" name="logoLink">
#      CL
#     </a>
#     <nav class="breadcrumbs-container">
#      <form action="/search/sss" class="breadcrumbs-form" data-action="/search/###/sss" id="breadcrumbform" method="get">
#       <input name="sort" type="hidden" value="rel"/>
#       <input name="query" type="hidden" value="guitar"/>
#       <ul class="breadcrumbs">
#        <li class="crumb area">
#         <span class="no-js">
#          <a href="/">
#           north jersey
#          </a>
#         </span>
#         <select class="js-only" id="areaAbb" name="areaAbb">
#          <option value="newjersey">
#           north jersey
#          </option>
#          <option value="albany">
#           albany, NY
#          </option>
#          <option value="allentown">
#           allentown
#          </option>
#          <option value="altoona">
#           altoona
#          </option>
#          <option value="annapolis">
#           annapolis
#          </option>
#          <option value="baltimore">
#           baltimore
#          </option>
#          <option value="binghamton">
#           binghamton
#          </option>
#          <option value="boston">
#           boston
#          </option>
#          <option value="capecod">
#           cape cod
#          </option>
#          <option value="catskills">
#           catskills
#          </option>
#          <option value="cnj">
#           central NJ
#          </option>
#          <option value="chambersburg">
#           cumberland val
#          </option>
#          <option value="delaware">
#           delaware
#          </option>
#          <option value="newlondon">
#           eastern CT
#          </option>
#          <option value="easternshore">
#           eastern shore
#          </option>
#          <option value="martinsburg">
#           eastern WV
#          </option>
#          <option value="elmira">
#           elmira
#          </option>
#          <option value="fingerlakes">
#           finger lakes
#          </option>
#          <option value="frederick">
#           frederick
#          </option>
#          <option value="glensfalls">
#           glens falls
#          </option>
#          <option value="harrisburg">
#           harrisburg
#          </option>
#          <option value="hartford">
#           hartford
#          </option>
#          <option value="hudsonvalley">
#           hudson valley
#          </option>
#          <option value="ithaca">
#           ithaca
#          </option>
#          <option value="jerseyshore">
#           jersey shore
#          </option>
#          <option value="lancaster">
#           lancaster, PA
#          </option>
#          <option value="longisland">
#           long island
#          </option>
#          <option value="nh">
#           new hampshire
#          </option>
#          <option value="newhaven">
#           new haven
#          </option>
#          <option value="newyork">
#           new york
#          </option>
#          <option value="nwct">
#           northwest CT
#          </option>
#          <option value="oneonta">
#           oneonta
#          </option>
#          <option value="philadelphia">
#           philadelphia
#          </option>
#          <option value="poconos">
#           poconos
#          </option>
#          <option value="reading">
#           reading
#          </option>
#          <option value="providence">
#           rhode island
#          </option>
#          <option value="scranton">
#           scranton
#          </option>
#          <option value="southcoast">
#           south coast
#          </option>
#          <option value="southjersey">
#           south jersey
#          </option>
#          <option value="smd">
#           southern MD
#          </option>
#          <option value="pennstate">
#           state college
#          </option>
#          <option value="syracuse">
#           syracuse
#          </option>
#          <option value="utica">
#           utica
#          </option>
#          <option value="washingtondc">
#           washington, DC
#          </option>
#          <option value="watertown">
#           watertown
#          </option>
#          <option value="westernmass">
#           western mass
#          </option>
#          <option value="williamsport">
#           williamsport
#          </option>
#          <option value="worcester">
#           worcester
#          </option>
#          <option value="york">
#           york, PA
#          </option>
#         </select>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </li>
#        <li class="crumb section">
#         <select id="catAbb" name="catAbb">
#          <option value="ccc">
#           community
#          </option>
#          <option value="eee">
#           events
#          </option>
#          <option selected="" value="sss">
#           for sale
#          </option>
#          <option value="ggg">
#           gigs
#          </option>
#          <option value="hhh">
#           housing
#          </option>
#          <option value="jjj">
#           jobs
#          </option>
#          <option value="rrr">
#           resumes
#          </option>
#          <option value="bbb">
#           services
#          </option>
#         </select>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </li>
#        <li class="crumb category">
#         <select class="js-only" id="subcatAbb">
#          <option value="sss">
#           all
#          </option>
#          <option value="ata">
#           antiques
#          </option>
#          <option value="ppa">
#           appliances
#          </option>
#          <option value="ara">
#           arts+crafts
#          </option>
#          <option value="sna">
#           atvs/utvs/snow
#          </option>
#          <option value="pta">
#           auto parts
#          </option>
#          <option value="wta">
#           auto wheels &amp; tires
#          </option>
#          <option value="ava">
#           aviation
#          </option>
#          <option value="baa">
#           baby+kids
#          </option>
#          <option value="bar">
#           barter
#          </option>
#          <option value="haa">
#           beauty+hlth
#          </option>
#          <option value="bip">
#           bike parts
#          </option>
#          <option value="bia">
#           bikes
#          </option>
#          <option value="bpa">
#           boat parts
#          </option>
#          <option value="boo">
#           boats
#          </option>
#          <option value="bka">
#           books
#          </option>
#          <option value="bfa">
#           business
#          </option>
#          <option value="cta">
#           cars+trucks
#          </option>
#          <option value="ema">
#           cds/dvd/vhs
#          </option>
#          <option value="moa">
#           cell phones
#          </option>
#          <option value="cla">
#           clothes+acc
#          </option>
#          <option value="cba">
#           collectibles
#          </option>
#          <option value="syp">
#           computer parts
#          </option>
#          <option value="sya">
#           computers
#          </option>
#          <option value="ela">
#           electronics
#          </option>
#          <option value="gra">
#           farm+garden
#          </option>
#          <option value="zip">
#           free stuff
#          </option>
#          <option value="fua">
#           furniture
#          </option>
#          <option value="gms">
#           garage sales
#          </option>
#          <option value="foa">
#           general
#          </option>
#          <option value="hva">
#           heavy equipment
#          </option>
#          <option value="hsa">
#           household
#          </option>
#          <option value="jwa">
#           jewelry
#          </option>
#          <option value="maa">
#           materials
#          </option>
#          <option value="mpa">
#           motorcycle parts
#          </option>
#          <option value="mca">
#           motorcycles
#          </option>
#          <option value="msa">
#           music instr
#          </option>
#          <option value="pha">
#           photo+video
#          </option>
#          <option value="rva">
#           RVs
#          </option>
#          <option value="sga">
#           sporting
#          </option>
#          <option value="tia">
#           tickets
#          </option>
#          <option value="tla">
#           tools
#          </option>
#          <option value="taa">
#           toys+games
#          </option>
#          <option value="tra">
#           trailers
#          </option>
#          <option value="vga">
#           video gaming
#          </option>
#          <option value="waa">
#           wanted
#          </option>
#         </select>
#         <span class="no-js">
#          for sale
#         </span>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </li>
#        <li class="crumb no-js">
#         <input type="submit" value="go"/>
#        </li>
#       </ul>
#      </form>
#     </nav>
#     <div class="userlinks">
#      <ul class="user-actions">
#       <li class="user post">
#        <a href="https://post.craigslist.org/c/njy">
#         post
#        </a>
#       </li>
#       <li class="user account">
#        <a href="https://accounts.craigslist.org/login/home">
#         account
#        </a>
#       </li>
#      </ul>
#      <ul class="user-favs-discards">
#       <li class="user">
#        <div class="favorites">
#         <a class="favlink" href="#">
#          <span aria-hidden="true" class="icon icon-star fav">
#          </span>
#          <span class="fav-number">
#           0
#          </span>
#          <span class="fav-label">
#           favorites
#          </span>
#         </a>
#        </div>
#       </li>
#       <li class="user discards">
#        <form action="/favorites" class="unfavform js-only" method="GET">
#         <div class="to-banish-page">
#          <input class="unfaves" name="fl" type="hidden"/>
#          <input name="uf" type="hidden" value="1"/>
#          <a class="to-banish-page-link" href="#">
#           <span aria-hidden="true" class="icon icon-trash red">
#           </span>
#           <span class="banished_count">
#            0
#           </span>
#           <span class="discards-label">
#            hidden
#           </span>
#          </a>
#         </div>
#        </form>
#       </li>
#      </ul>
#     </div>
#    </header>
#    <header class="global-header narrow">
#     <a class="header-logo" href="/">
#      CL
#     </a>
#     <nav class="breadcrumbs-container">
#      <h1 class="breadcrumbs">
#       north jersey            &gt;
#
# for sale
#      </h1>
#     </nav>
#     <span class="linklike show-wide-header">
#      ...
#     </span>
#    </header>
#    <form action="/d/for-sale/search/sss" class="search-form" id="searchform">
#     <div class="querybox">
#      <div class="form-tab js-only">
#       <span class="search-open" title="hide search">
#        «
#       </span>
#       <span class="search-closed" title="show search">
#        »
#       </span>
#      </div>
#      <input autocapitalize="off" autocomplete="off" autocorrect="off" class="flatinput ui-autocomplete-input" data-autocomplete="search" id="query" name="query" placeholder="search for sale" type="text" value="guitar"/>
#      <button class="searchbtn" type="submit">
#       <span aria-hidden="true" class="icon icon-search">
#       </span>
#       <span class="screen-reader-text">
#        press to search craigslist
#       </span>
#      </button>
#      <div class="savealert">
#       <a class="saveme" data-action="save" href="https://accounts.craigslist.org/savesearch/save?URL=https%3A%2F%2Fnewjersey%2Ecraigslist%2Eorg%2Fd%2Ffor%2Dsale%2Fsearch%2Fsss%3Fquery%3Dguitar%26sort%3Drel" title="save this search">
#        save search
#       </a>
#      </div>
#     </div>
#     <div class="search-options-container">
#      <h1 class="cattitle">
#       <a class="reset" href="/d/for-sale/search/sss" title="clear all search parameters">
#        for sale
#       </a>
#      </h1>
#      <div class="search-options-header linklike">
#       <div aria-hidden="true" class="icon icon-toggle-gear">
#       </div>
#       options
#       <span class="options-close">
#        close
#       </span>
#      </div>
#      <input id="excats" name="excats" type="hidden"/>
#      <input name="sort" type="hidden" value="rel"/>
#      <div class="search-options">
#       <div class="searchgroup categories">
#        <ul class="maincats">
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="msa" id="cat_msa" name="cat_id" type="checkbox" value="98,184"/>
#          <a class="category" href="/d/musical-instruments/search/msa?query=guitar&amp;sort=rel">
#           musical instruments
#          </a>
#          <span class="count">
#           394
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="waa" id="cat_waa" name="cat_id" type="checkbox" value="20,190"/>
#          <a class="category" href="/d/wanted/search/waa?query=guitar&amp;sort=rel">
#           wanted
#          </a>
#          <span class="count">
#           20
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="ela" id="cat_ela" name="cat_id" type="checkbox" value="96,167"/>
#          <a class="category" href="/d/electronics/search/ela?query=guitar&amp;sort=rel">
#           electronics
#          </a>
#          <span class="count">
#           16
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="vga" id="cat_vga" name="cat_id" type="checkbox" value="151,189"/>
#          <a class="category" href="/d/video-gaming/search/vga?query=guitar&amp;sort=rel">
#           video gaming
#          </a>
#          <span class="count">
#           14
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="foa" id="cat_foa" name="cat_id" type="checkbox" value="5,179"/>
#          <a class="category" href="/d/general-for-sale/search/foa?query=guitar&amp;sort=rel">
#           general for sale
#          </a>
#          <span class="count">
#           12
#          </span>
#         </li>
#         <li class="morecats js-only closed">
#          <span class="linklike closed">
#           <span class="plusminus">
#            +
#           </span>
#           show 40 more
#          </span>
#          <span class="linklike open">
#           <span class="plusminus">
#            –
#           </span>
#           hide 40 more
#          </span>
#          <span class="count">
#           65
#          </span>
#         </li>
#        </ul>
#        <ul class="othercats closed">
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="taa" id="cat_taa" name="cat_id" type="checkbox" value="132,188"/>
#          <a class="category" href="/d/toys-games/search/taa?query=guitar&amp;sort=rel">
#           toys &amp; games
#          </a>
#          <span class="count">
#           10
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="gms" id="cat_gms" name="cat_id" type="checkbox" value="73"/>
#          <a class="category" href="/d/garage-moving-sales/search/gms?query=guitar&amp;sort=rel">
#           garage &amp; moving sales
#          </a>
#          <span class="count">
#           9
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="cba" id="cat_cba" name="cat_id" type="checkbox" value="95,177"/>
#          <a class="category" href="/d/collectibles/search/cba?query=guitar&amp;sort=rel">
#           collectibles
#          </a>
#          <span class="count">
#           8
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="fua" id="cat_fua" name="cat_id" type="checkbox" value="141,142"/>
#          <a class="category" href="/d/furniture/search/fua?query=guitar&amp;sort=rel">
#           furniture
#          </a>
#          <span class="count">
#           8
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="ara" id="cat_ara" name="cat_id" type="checkbox" value="135,170"/>
#          <a class="category" href="/d/arts-crafts/search/ara?query=guitar&amp;sort=rel">
#           arts &amp; crafts
#          </a>
#          <span class="count">
#           5
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="bar" id="cat_bar" name="cat_id" type="checkbox" value="42"/>
#          <a class="category" href="/d/barter/search/bar?query=guitar&amp;sort=rel">
#           barter
#          </a>
#          <span class="count">
#           4
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="baa" id="cat_baa" name="cat_id" type="checkbox" value="107,171"/>
#          <a class="category" href="/d/baby-kid-stuff/search/baa?query=guitar&amp;sort=rel">
#           baby &amp; kid stuff
#          </a>
#          <span class="count">
#           3
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="bka" id="cat_bka" name="cat_id" type="checkbox" value="92,173"/>
#          <a class="category" href="/d/books-magazines/search/bka?query=guitar&amp;sort=rel">
#           books &amp; magazines
#          </a>
#          <span class="count">
#           3
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="ema" id="cat_ema" name="cat_id" type="checkbox" value="117,175"/>
#          <a class="category" href="/d/cds-dvds-vhs/search/ema?query=guitar&amp;sort=rel">
#           cds / dvds / vhs
#          </a>
#          <span class="count">
#           3
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="zip" id="cat_zip" name="cat_id" type="checkbox" value="101"/>
#          <a class="category" href="/d/free-stuff/search/zip?query=guitar&amp;sort=rel">
#           free stuff
#          </a>
#          <span class="count">
#           3
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="ata" id="cat_ata" name="cat_id" type="checkbox" value="150,169"/>
#          <a class="category" href="/d/antiques/search/ata?query=guitar&amp;sort=rel">
#           antiques
#          </a>
#          <span class="count">
#           2
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="bia" id="cat_bia" name="cat_id" type="checkbox" value="68,172"/>
#          <a class="category" href="/d/bicycles/search/bia?query=guitar&amp;sort=rel">
#           bicycles
#          </a>
#          <span class="count">
#           2
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="bfa" id="cat_bfa" name="cat_id" type="checkbox" value="134,174"/>
#          <a class="category" href="/d/business/search/bfa?query=guitar&amp;sort=rel">
#           business
#          </a>
#          <span class="count">
#           1
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="cta" id="cat_cta" name="cat_id" type="checkbox" value="145,146"/>
#          <a class="category" href="/d/cars-trucks/search/cta?query=guitar&amp;sort=rel">
#           cars &amp; trucks
#          </a>
#          <span class="count">
#           1
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="cla" id="cat_cla" name="cat_id" type="checkbox" value="94,176"/>
#          <a class="category" href="/d/clothing-accessories/search/cla?query=guitar&amp;sort=rel">
#           clothing &amp; accessories
#          </a>
#          <span class="count">
#           1
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="pha" id="cat_pha" name="cat_id" type="checkbox" value="137,185"/>
#          <a class="category" href="/d/photo-video/search/pha?query=guitar&amp;sort=rel">
#           photo/video
#          </a>
#          <span class="count">
#           1
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="tia" id="cat_tia" name="cat_id" type="checkbox" value="44,161"/>
#          <a class="category" href="/d/tickets/search/tia?query=guitar&amp;sort=rel">
#           tickets
#          </a>
#          <span class="count">
#           1
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="ppa" id="cat_ppa" name="cat_id" type="checkbox" value="149,162"/>
#          <a class="category" href="/d/appliances/search/ppa?query=guitar&amp;sort=rel">
#           appliances
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="sna" id="cat_sna" name="cat_id" type="checkbox" value="191,192"/>
#          <a class="category" href="/d/atvs%2C-utvs%2C-snowmobiles/search/sna?query=guitar&amp;sort=rel">
#           atvs, utvs, snowmobiles
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="pta" id="cat_pta" name="cat_id" type="checkbox" value="122,163"/>
#          <a class="category" href="/d/auto-parts/search/pta?query=guitar&amp;sort=rel">
#           auto parts
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="wta" id="cat_wta" name="cat_id" type="checkbox" value="203,204"/>
#          <a class="category" href="/d/auto-wheels-tires/search/wta?query=guitar&amp;sort=rel">
#           auto wheels &amp; tires
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="ava" id="cat_ava" name="cat_id" type="checkbox" value="208,209"/>
#          <a class="category" href="/d/aviation/search/ava?query=guitar&amp;sort=rel">
#           aviation
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="bip" id="cat_bip" name="cat_id" type="checkbox" value="197,198"/>
#          <a class="category" href="/d/bicycle-parts/search/bip?query=guitar&amp;sort=rel">
#           bicycle parts
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="bpa" id="cat_bpa" name="cat_id" type="checkbox" value="201,202"/>
#          <a class="category" href="/d/boat-parts-accessories/search/bpa?query=guitar&amp;sort=rel">
#           boat parts &amp; accessories
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="boo" id="cat_boo" name="cat_id" type="checkbox" value="119,164"/>
#          <a class="category" href="/d/boats/search/boo?query=guitar&amp;sort=rel">
#           boats
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="moa" id="cat_moa" name="cat_id" type="checkbox" value="153,165"/>
#          <a class="category" href="/d/cell-phones/search/moa?query=guitar&amp;sort=rel">
#           cell phones
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="syp" id="cat_syp" name="cat_id" type="checkbox" value="199,200"/>
#          <a class="category" href="/d/computer-parts/search/syp?query=guitar&amp;sort=rel">
#           computer parts
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="sya" id="cat_sya" name="cat_id" type="checkbox" value="7,166"/>
#          <a class="category" href="/d/computers/search/sya?query=guitar&amp;sort=rel">
#           computers
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="gra" id="cat_gra" name="cat_id" type="checkbox" value="133,178"/>
#          <a class="category" href="/d/farm-garden/search/gra?query=guitar&amp;sort=rel">
#           farm &amp; garden
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="haa" id="cat_haa" name="cat_id" type="checkbox" value="152,180"/>
#          <a class="category" href="/d/health-and-beauty/search/haa?query=guitar&amp;sort=rel">
#           health and beauty
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="hva" id="cat_hva" name="cat_id" type="checkbox" value="193,194"/>
#          <a class="category" href="/d/heavy-equipment/search/hva?query=guitar&amp;sort=rel">
#           heavy equipment
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="hsa" id="cat_hsa" name="cat_id" type="checkbox" value="97,181"/>
#          <a class="category" href="/d/household-items/search/hsa?query=guitar&amp;sort=rel">
#           household items
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="jwa" id="cat_jwa" name="cat_id" type="checkbox" value="120,182"/>
#          <a class="category" href="/d/jewelry/search/jwa?query=guitar&amp;sort=rel">
#           jewelry
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="maa" id="cat_maa" name="cat_id" type="checkbox" value="136,183"/>
#          <a class="category" href="/d/materials/search/maa?query=guitar&amp;sort=rel">
#           materials
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="mpa" id="cat_mpa" name="cat_id" type="checkbox" value="195,196"/>
#          <a class="category" href="/d/motorcycle-parts-accessories/search/mpa?query=guitar&amp;sort=rel">
#           motorcycle parts &amp; accessories
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="mca" id="cat_mca" name="cat_id" type="checkbox" value="69,160"/>
#          <a class="category" href="/d/motorcycles-scooters/search/mca?query=guitar&amp;sort=rel">
#           motorcycles/scooters
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="rva" id="cat_rva" name="cat_id" type="checkbox" value="124,168"/>
#          <a class="category" href="/d/recreational-vehicles/search/rva?query=guitar&amp;sort=rel">
#           recreational vehicles
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="sga" id="cat_sga" name="cat_id" type="checkbox" value="93,186"/>
#          <a class="category" href="/d/sporting-goods/search/sga?query=guitar&amp;sort=rel">
#           sporting goods
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="tla" id="cat_tla" name="cat_id" type="checkbox" value="118,187"/>
#          <a class="category" href="/d/tools/search/tla?query=guitar&amp;sort=rel">
#           tools
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="tra" id="cat_tra" name="cat_id" type="checkbox" value="205,206"/>
#          <a class="category" href="/d/trailers/search/tra?query=guitar&amp;sort=rel">
#           trailers
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#        </ul>
#        <div class="selectall js-only checked">
#         <label>
#          <input checked="checked" class="catcheck selectallcb" type="checkbox"/>
#          <span class="all linklike">
#           select all
#          </span>
#         </label>
#        </div>
#       </div>
#       <input name="userid" type="hidden" value="">
#        <ul class="searchgroup buttongroup purveyor">
#         <li class="button sel">
#          <a data-val="all" href="/d/for-sale/search/sss?query=guitar&amp;sort=rel">
#           all
#          </a>
#         </li>
#         <li class="button">
#          <a data-val="owner" href="/d/for-sale-by-owner/search/sso?query=guitar&amp;sort=rel">
#           owner
#          </a>
#         </li>
#         <li class="button">
#          <a data-val="dealer" href="/d/for-sale-by-dealer/search/ssq?query=guitar&amp;sort=rel">
#           dealer
#          </a>
#         </li>
#        </ul>
#        <div class="searchgroup">
#         <ul>
#          <li>
#           <label class="srchType">
#            <input class="" name="srchType" type="checkbox" value="T"/>
#            search titles only
#           </label>
#          </li>
#          <li>
#           <label class="hasPic">
#            <input class="autosubmit" name="hasPic" type="checkbox" value="1"/>
#            has image
#           </label>
#          </li>
#          <li>
#           <label class="postedToday">
#            <input class="autosubmit" name="postedToday" type="checkbox" value="1"/>
#            posted today
#           </label>
#          </li>
#          <li>
#           <label class="bundleDuplicates">
#            <input class="autosubmit" name="bundleDuplicates" type="checkbox" value="1"/>
#            bundle duplicates
#           </label>
#          </li>
#          <li>
#           <label class="searchNearby">
#            <input class="autosubmit" name="searchNearby" type="checkbox" value="1"/>
#            include nearby areas
#           </label>
#          </li>
#         </ul>
#         <ul class="js-only nearbyAreas">
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_19" name="nearbyArea" type="checkbox" value="59">
#             albany, NY
#             <small>
#              (alb)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_7">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_44" name="nearbyArea" type="checkbox" value="355">
#             altoona-johnstown
#             <small>
#              (aoo)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_6">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_36" name="nearbyArea" type="checkbox" value="460">
#             annapolis, MD
#             <small>
#              (anp)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_5">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_32" name="nearbyArea" type="checkbox" value="34">
#             baltimore, MD
#             <small>
#              (bal)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_18" name="nearbyArea" type="checkbox" value="248">
#             binghamton, NY
#             <small>
#              (bgm)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_6">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_37" name="nearbyArea" type="checkbox" value="4">
#             boston
#             <small>
#              (bos)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_9">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_56" name="nearbyArea" type="checkbox" value="40">
#             buffalo, NY
#             <small>
#              (buf)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_7">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_42" name="nearbyArea" type="checkbox" value="239">
#             cape cod / islands
#             <small>
#              (cap)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_8" name="nearbyArea" type="checkbox" value="451">
#             catskills
#             <small>
#              (cat)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_1" name="nearbyArea" type="checkbox" value="349">
#             central NJ
#             <small>
#              (cnj)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_10">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_61" name="nearbyArea" type="checkbox" value="290">
#             charlottesville, VA
#             <small>
#              (uva)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_9">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_57" name="nearbyArea" type="checkbox" value="452">
#             chautauqua, NY
#             <small>
#              (chq)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_6">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_39" name="nearbyArea" type="checkbox" value="705">
#             cumberland valley
#             <small>
#              (cbg)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_21" name="nearbyArea" type="checkbox" value="193">
#             delaware
#             <small>
#              (dlw)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_2">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_15" name="nearbyArea" type="checkbox" value="281">
#             eastern CT
#             <small>
#              (nlo)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_7">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_45" name="nearbyArea" type="checkbox" value="444">
#             eastern panhandle
#             <small>
#              (ewv)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_5">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_34" name="nearbyArea" type="checkbox" value="328">
#             eastern shore
#             <small>
#              (esh)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_4">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_27" name="nearbyArea" type="checkbox" value="453">
#             elmira-corning
#             <small>
#              (elm)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_5">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_33" name="nearbyArea" type="checkbox" value="685">
#             finger lakes, NY
#             <small>
#              (fgl)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_6">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_40" name="nearbyArea" type="checkbox" value="633">
#             frederick, MD
#             <small>
#              (fdk)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_8">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_51" name="nearbyArea" type="checkbox" value="457">
#             fredericksburg, VA
#             <small>
#              (ezf)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_5">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_30" name="nearbyArea" type="checkbox" value="686">
#             glens falls, NY
#             <small>
#              (gfl)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_22" name="nearbyArea" type="checkbox" value="166">
#             harrisburg, PA
#             <small>
#              (hrs)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_9">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_59" name="nearbyArea" type="checkbox" value="447">
#             harrisonburg, VA
#             <small>
#              (shd)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_2">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_12" name="nearbyArea" type="checkbox" value="44">
#             hartford, CT
#             <small>
#              (htf)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_3" name="nearbyArea" type="checkbox" value="249">
#             hudson valley, NY
#             <small>
#              (hud)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_4">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_28" name="nearbyArea" type="checkbox" value="201">
#             ithaca, NY
#             <small>
#              (ith)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_2" name="nearbyArea" type="checkbox" value="561">
#             jersey shore
#             <small>
#              (jys)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_20" name="nearbyArea" type="checkbox" value="279">
#             lancaster, PA
#             <small>
#              (lns)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_7" name="nearbyArea" type="checkbox" value="167">
#             lehigh valley
#             <small>
#              (alt)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_4" name="nearbyArea" type="checkbox" value="250">
#             long island, NY
#             <small>
#              (isp)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_7">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_47" name="nearbyArea" type="checkbox" value="198">
#             new hampshire
#             <small>
#              (nhm)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_6" name="nearbyArea" type="checkbox" value="168">
#             new haven, CT
#             <small>
#              (hvn)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_0" name="nearbyArea" type="checkbox" value="3">
#             new york city
#             <small>
#              (nyc)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_10">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_60" name="nearbyArea" type="checkbox" value="48">
#             norfolk / hampton roads
#             <small>
#              (nfk)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
# ...
#           Guitar stand for 3 guitars
#          </a>
#         </h3>
#         <span class="result-meta">
#          <span class="result-price">
#           $20
#          </span>
#          <span class="result-hood">
#           (Franklin Lakes)
#          </span>
#          <span class="result-tags">
#           <span class="pictag">
#            pic
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </div>
#       </li>
#       <li class="result-row" data-pid="7243230711" data-repost-of="7142078137">
#        <a class="result-image gallery" data-ids="3:00D0D_6pqdCTQapAo_0mA0g8,3:00F0F_5pAqg3bgAAd_0CI0lM,3:00y0y_8kg8G6YFoMJ_0CI0lM,3:00A0A_gO12f6oWQKj_0gl0t2,3:00606_cuGfEKeFBrV_0CI0lM,3:00G0G_4LlWsHoQipr_04k0bn,3:00A0A_4w6avfKttqx_0bX09r,3:00L0L_bCd7uTM5zwO_0c507Z,3:00s0s_iWczZj1wZGx_0cK06e,3:00909_iZl09msYSZu_0px0bB" href="https://newjersey.craigslist.org/msg/d/rochelle-park-fender-fe1225-electric/7243230711.html">
#         <span class="result-price">
#          $0
#         </span>
#        </a>
#        <div class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2020-12-07 12:51" title="Mon 07 Dec 12:51:48 PM">
#          Dec  7
#         </time>
#         <h3 class="result-heading">
#          <a class="result-title hdrlnk" data-id="7243230711" href="https://newjersey.craigslist.org/msg/d/rochelle-park-fender-fe1225-electric/7243230711.html" id="postid_7243230711">
#           Fender FE1225 Electric Guitar Gig Bag - Black - Top of the Line - NEW!
#          </a>
#         </h3>
#         <span class="result-meta">
#          <span class="result-price">
#           $0
#          </span>
#          <span class="result-tags">
#           <span class="pictag">
#            pic
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </div>
#       </li>
#       <li class="result-row" data-pid="7239426017">
#        <a class="result-image gallery" data-ids="3:00C0C_fMSTJOgPNWs_0CI0ju,3:00v0v_bhuhzcWoRgg_0CI0t2,3:00d0d_8sMK1oHmM58_0pQ0mz,3:00B0B_cSIfpt8xknK_0CI0gJ,3:00t0t_2yrIVj9BF5N_0CI0t2,3:00M0M_eRU97ZGXdmT_0CI0nF,3:00v0v_doEM1KqWuts_0AU0nX,3:00808_fgWyMlQWtpY_0CI0t2,3:00f0f_52skWl8Eey2_0CI0ii,3:00Q0Q_je7mq9Zir1q_0CI0p4" href="https://newjersey.craigslist.org/msg/d/dover-martin-18-guitar/7239426017.html">
#         <span class="result-price">
#          $1,750
#         </span>
#        </a>
#        <div class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2020-12-06 22:26" title="Sun 06 Dec 10:26:39 PM">
#          Dec  6
#         </time>
#         <h3 class="result-heading">
#          <a class="result-title hdrlnk" data-id="7239426017" href="https://newjersey.craigslist.org/msg/d/dover-martin-18-guitar/7239426017.html" id="postid_7239426017">
#           Martin D-18 Guitar
#          </a>
#         </h3>
#         <span class="result-meta">
#          <span class="result-price">
#           $1,750
#          </span>
#          <span class="result-hood">
#           (N.Jersey)
#          </span>
#          <span class="result-tags">
#           <span class="pictag">
#            pic
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </div>
#       </li>
#       <li class="result-row" data-pid="7228394033">
#        <a class="result-image gallery" data-ids="3:00b0b_jxHE9eeaBXE_0fu0t2,3:00z0z_jQxciCVzVL9_0eQ0t2,3:00t0t_6qDmDXzDtC6_0fb0t2,3:00404_6G1DMlZRjxr_0t20t2" href="https://newjersey.craigslist.org/msg/d/union-dean-edge-09-electric-bass-guitar/7228394033.html">
#         <span class="result-price">
#          $175
#         </span>
#        </a>
#        <div class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2020-12-06 22:10" title="Sun 06 Dec 10:10:43 PM">
#          Dec  6
#         </time>
#         <h3 class="result-heading">
#          <a class="result-title hdrlnk" data-id="7228394033" href="https://newjersey.craigslist.org/msg/d/union-dean-edge-09-electric-bass-guitar/7228394033.html" id="postid_7228394033">
#           Dean Edge 09 Electric Bass Guitar
#          </a>
#         </h3>
#         <span class="result-meta">
#          <span class="result-price">
#           $175
#          </span>
#          <span class="result-hood">
#           (Union)
#          </span>
#          <span class="result-tags">
#           <span class="pictag">
#            pic
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </div>
#       </li>
#      </ul>
#     </div>
#     <div class="search-legend bottom">
#      <div class="search-view">
#       <span class="buttongroup">
#        <a class="backtotop button" href="#page-top">
#         ^ back to top
#        </a>
#       </span>
#      </div>
#      <div class="search-sort">
#       <span class="buttongroup">
#        <a class="backtotop button" href="#page-top">
#         ^ back to top
#        </a>
#       </span>
#      </div>
#      <div class="paginator buttongroup firstpage">
#       <span class="resulttotal">
#        <span class="for-map">
#         showing
#         <span class="displaycountShow">
#          ...
#         </span>
#         postings
#         <span class="zoom-out-for-more" style="display: none">
#          -
#          <a href="">
#           zoom out for all
#           <span class="total">
#            512
#           </span>
#          </a>
#         </span>
#        </span>
#       </span>
#       <span class="buttons">
#        <a class="button first" href="/d/for-sale/search/sss?query=guitar&amp;sort=rel" title="first page">
#         &lt;&lt;
#        </a>
#        <span class="button first" title="first page">
#         &lt;&lt;
#        </span>
#        <a class="button prev" href="/d/for-sale/search/sss?query=guitar&amp;sort=rel" title="previous page">
#         &lt; prev
#        </a>
#        <span class="button prev" title="previous page">
#         &lt; prev
#        </span>
#        <span class="button pagenum">
#         <span class="range">
#          <span class="rangeFrom">
#           1
#          </span>
#          -
#          <span class="rangeTo">
#           120
#          </span>
#         </span>
#         /
#         <span class="totalcount">
#          512
#         </span>
#        </span>
#        <a class="button next" href="/d/for-sale/search/sss?s=120&amp;query=guitar&amp;sort=rel" title="next page">
#         next &gt;
#        </a>
#        <span class="button next" title="next page">
#         next &gt;
#        </span>
#       </span>
#      </div>
#     </div>
#     <section class="blurbs">
#     </section>
#     <div id="floater">
#      <img alt="" class="loading" src="//www.craigslist.org/images/animated-spinny.gif"/>
#      <img alt="" class="payload" src="//www.craigslist.org/images/animated-spinny.gif"/>
#     </div>
#    </form>
#    <aside class="tsb">
#     <ul>
#      <li>
#       <a href="https://www.craigslist.org/about/safety">
#        safety tips
#       </a>
#       <li>
#        <a href="https://www.craigslist.org/about/prohibited">
#         prohibited items
#        </a>
#        <li>
#         <a href="https://www.craigslist.org/about/recalled_items">
#          product recalls
#         </a>
#         <li>
#          <a href="https://www.craigslist.org/about/scams">
#           avoiding scams
#          </a>
#         </li>
#        </li>
#       </li>
#      </li>
#     </ul>
#    </aside>
#    <div class="slidemessage">
#     <span class="fave">
#      <span class="star">
#      </span>
#      favorited
#     </span>
#     <span class="unfave">
#      <span class="star">
#      </span>
#      no longer favorited
#     </span>
#     <span class="hide">
#      <span class="trash">
#      </span>
#      hidden
#     </span>
#     <span class="unhide">
#      <span class="trash">
#      </span>
#      no longer hidden
#     </span>
#    </div>
#    <footer>
#     <ul class="clfooter">
#      <li>
#       © 2020
#       <span class="desktop">
#        craigslist
#       </span>
#       <span class="mobile">
#        CL
#       </span>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/help/">
#        help
#       </a>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/scams">
#        safety
#       </a>
#      </li>
#      <li class="desktop">
#       <a href="https://www.craigslist.org/about/privacy.policy">
#        privacy
#       </a>
#       <sup class="neu">
#        new
#       </sup>
#      </li>
#      <li class="desktop">
#       <a href="https://forums.craigslist.org/?forumID=8">
#        feedback
#       </a>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/terms.of.use">
#        terms
#       </a>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/">
#        about
#       </a>
#      </li>
#      <li class="fsel desktop linklike" data-mode="mobile">
#       mobile
#      </li>
#      <li class="fsel mobile linklike" data-mode="regular">
#       desktop
#      </li>
#     </ul>
#    </footer>
#   </section>
#   <template id="gallerycarousel">
#    <div class="slider-info">
#    </div>
#    <div class="slider-back arrow">
#     &lt;
#    </div>
#    <div class="slider-forward arrow">
#     &gt;
#    </div>
#   </template>
#   <script>
#    try {
#                     if (
#                         !/\/\/.+\.craigslist\.org\/about\//.test(window.location.href)
#                         &&
#                         (!window.addEventListener || JSON.parse(JSON.stringify('x')) !== 'x')
#                     ) {
#                         throw "unsupported browser";
#                     }
#                 } catch (e) {
#                     function cleanup() {
#                         document.body.innerHTML = '<div id="cl-unsupported-browser" style="margin:1em;font-size:150%;text-align:center;">We have detected you are using a browser that is missing critical features.<br><br>Please visit craigslist from a modern browser.</div>';
#                         document.body.style = "display:block";
#                     }
#
#                     try {
#                         document.body.style = "display:none";
#                     } catch (e) {
#                     }
#                     window.onload = cleanup;
#                     window.clUnsupportedBrowser = true;
#                 }
#   </script>
#   <script src="//www.craigslist.org/js/general-concat.min.js?v=cc74ec54f2e664e8ffc850ce866063e4" type="text/javascript">
#   </script>
#   <script id="clustertemplate" type="text/template">
#    <li class="posting {visited}" data-pid="{PostingID}">
#         <img src="{ImageThumb}">
#         <div class="housing_bubble_banner">
#             <span class="{hasPrice}price">{currencySymbol}{price}</span>
#             <span class="bedrooms">{BedroomsContent}</span>
#             <span class="postingtitle"><a>{PostingTitle}</a></span>
#             <span class="js-only map-banish-unbanish" data-pid="{PostingID}">
#                 <span class="banish">
#                     <span class="icon icon-trash" role="button"></span>
#                     <span class="screen-reader-text">hide this posting</span>
#                 </span>
#                 <span class="unbanish">
#                     <span class="icon icon-trash red" role="button"></span>
#                     unhide
#                 </span>
#             </span>
#         </div>
#     </li>
#   </script>
#   <script id="postingtemplate" type="text/template">
#    <div class="viewcontainer pics loading">
#         <div class="backtolist">
#             &laquo; back to posting list
#         </div>
#         <div class="title">
#             <span class="icon icon-star" data-pid="{PostingID}" role="button">
#                 <span class="screen-reader-text">favorite this post</span>
#             </span>
#             <span class="postingtitle">
#                 <a href="{PostingURL}" target="_blank">{PostingTitle}</a>
#             </span>
#             <div>
#                 <span class="{hasPrice}price">{currencySymbol}{price}</span>
#                 <span class="bedrooms">{BedroomsContent}</span>
#                 <span class="js-only map-banish-unbanish" data-pid="{PostingID}">
#                     <span class="banish">
#                         <span class="icon icon-trash" role="button"></span>
#                         <span class="screen-reader-text">hide this posting</span>
#                     </span>
#                     <span class="unbanish">
#                         <span class="icon icon-trash red" role="button"></span>
#                         <span class="screen-reader-text">unhide</span>
#                         unhide
#                     </span>
#                 </span>
#             </div>
#         </div>
#         <hr style="clear:both">
#         <div class="picscontainer gallery">
#             <span class="slider-back arrow">&lt;</span><span class="slider-info"></span><span class="slider-forward arrow">&gt;</span>
#             <div class="swipe">
#                 <div class="swipe-wrap">
#                     <img class="loading" src="//www.craigslist.org/images/animated-spinny.gif" alt="">
#                 </div>
#             </div>
#         </div>
#         <div class="infocontainer"></div>
#         <hr style="clear:both">
#         <div class="timecontainer"></div>
#         <a class="viewpostinglink" href="{PostingURL}" target="_blank">view posting</a>
#         <div class="contenttoggle">
#             <a class="moreinfo">more info</a>
#             <a class="showpics">show images</a>
#         </div>
#     </div>
#   </script>
#   <script id="popuptemplate" type="text/template">
#    <div id="mapbubble" class="posting">
#         <ul id="clusterbubble"></ul>
#         <div id="postbubble"></div>
#     </div>
#   </script>
#   <script src="//www.craigslist.org/js/leaflet-concat.min.js?v=66cc485807e67440f6b0d8f1fbced8ae" type="text/javascript">
#   </script>
#   <script src="//www.craigslist.org/js/search-concat.min.js?v=5d3d34bc2c54e77c538fa0b62b5e3f99" type="text/javascript">
#   </script>
#   <script src="//www.craigslist.org/js/postings-concat.min.js?v=3058fa59c3b717b34a9948ccc55101e1" type="text/javascript">
#   </script>
#  </body>
# </html>

# %%
# results are returned as an iterable list
results = soup.find_all('li', class_="result-row")
len(results)
# Out:
# 120

# %%
# Loop through returned results
for result in results:
    # Error handling
    try:
        # Identify and return title of listing
        title = result.find('a', class_="result-title").text
        # Identify and return price of listing
        #price = result.a.span.text
        price = result.find('span', class_='result-price').text
        # Identify and return link to listing
        link = result.a['href']

        # Print results only if title, price, and link are available
        if (title and price and link):
            print('-------------')
            print(title)
            print(price)
            print(link)
    except Exception as e:
        print(e)
# Out:
# -------------
# 1970 MIJ SG Style Guitar - Natural
# $595
# https://newjersey.craigslist.org/msg/d/pearl-river-1970-mij-sg-style-guitar/7248865110.html
# -------------
# Sesame Street guitar, great cond
# $8
# https://newjersey.craigslist.org/bab/d/montville-sesame-street-guitar-great/7243513074.html
# -------------
# Sesame Street guitar, great cond
# $8
