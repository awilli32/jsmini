# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import pymongo

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection
db = client.nhl_db
collection = db.articles

# %%
# URL of page to be scraped
url = 'https://www.nhl.com/news'

# Retrieve page with the requests module
response = requests.get(url)
# Create BeautifulSoup object; parse with 'html.parser'
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# Retrieve the parent divs for all articles
results = soup.find_all('div', class_='article-item__top')

# loop over results to get article data
for result in results:
    # scrape the article header 
    header = result.find('h1', class_='article-item__headline').text
    
    # scrape the article subheader
    subheader = result.find('h2', class_='article-item__subheader').text
    
    # scrape the datetime
    datetime = result.find('span', class_='article-item__date')['data-date'] 
    
    # get only the date from the datetime
    date = datetime.split('T')[0]
    
    # print article data
    print('-----------------')
    print(header)
    print(subheader)
    print(date)

    # Dictionary to be inserted into MongoDB
    post = {
        'header': header,
        'subheader': subheader,
        'date': date,
    }

    # Insert dictionary into MongoDB as a document
    collection.update_one(
        {
            'header':header,
            'subheader':subheader,
            'date':'date'
        },
        {'$set': {
            'header':header,
            'subheader':subheader,
            'date':date
            }
        },
        upsert=True
    )
# Out:
# -----------------
# NHL season would start Jan. 13, play 56 games in agreement with NHLPA
# Tentative deal includes Canada division, needs approval
# 2020-12-18
# -----------------
# MacKinnon says Avalanche may be favorites to win Stanley Cup
# Hart Trophy finalist helped Colorado reach Western Conference Second Round last season
# 2020-12-18
# -----------------
# Dach named Canada captain for World Juniors
# Blackhawks center learns he was chosen for role in McDavid video announcement
# 2020-12-18
# -----------------
# Lundqvist won't play for Capitals this season because of heart condition
# Goalie signed one-year contract Oct. 9 to share time with Samsonov after bought out by Rangers
# 2020-12-17
# -----------------
# Finland all-time WJC starting lineup includes Teravainen, Laine
# Tikkanen, Numminen, Lehtonen also on team picked by NHL.com
# 2020-12-19
# -----------------
# Reverse Retro alternate jerseys for all 31 teams unveiled by NHL, adidas
# Now available for purchase, will be worn multiple times this season
# 2020-12-01
# -----------------
# Super 16: Top NHL forwards
# McDavid, MacKinnon, Crosby among best in NHL.com rankings
# 2020-12-17
# -----------------
# Germany has eight players test positive for COVID-19 at World Juniors
# Will remain quarantined until Dec. 24; Sweden also in extended isolation
# 2020-12-18
# -----------------
# Holtby working with Indigenous artist on new mask for Canucks
# Goalie apologized after helmet designed by Swedish artist sparked cultural appropriation calls
# 2020-12-18
# -----------------
# Fantasy top 10 sleeper candidates for 2020-21
# NHL.com lists potential steals attainable in late rounds; season preview podcast
# 2020-12-18
# -----------------
# NHL.com holiday gift guide
# From hoodies to jerseys to collectibles, can't-miss items for hockey fans on your list
# 2020-11-27
# -----------------
# Flames executive Snow adjusting to feeding tube in ALS treatment
# Assistant GM had surgery this month after setback during clinical trial
# 2020-12-18
# -----------------
# Lundqvist heart condition has Capitals facing uncertainty at goalie
# 38-year-old out for season, was expected to share time with Samsonov
# 2020-12-17
# -----------------
# Steen retires from NHL after 15 seasons
# 36-year-old forward had back injury, won Stanley Cup with Blues in 2019
# 2020-12-17
# -----------------
# 2021 World Junior Championship schedule
# Tournament to start Dec. 25, will be played in Edmonton bubble without fans
# 2020-12-14
# -----------------
# NHL Free Agent Tracker
# Complete list of signings by team, available players
# 2020-12-18
# -----------------
# Sweden all-time WJC starting lineup includes Peter Forsberg, Karlsson
# Naslund, Filip Forsberg round out first line of team picked by NHL.com
# 2020-12-18
# -----------------
# Duclair agrees to one-year contract with Panthers
# Free agent forward scored NHL career-high 23 goals last season
# 2020-12-17
# -----------------
# Lundqvist's current, former teammates show support on social media
# Players share well wishes for veteran goalie who revealed heart condition
# 2020-12-17
# -----------------
# NHL free agent signings fantasy roundup
# Fantasy spin: Duclair to Panthers; impact of Pietrangelo, Hall, Krug moves
# 2020-12-18
# -----------------
# 2020-21 NHL Trade Tracker
# Official deals since Oct. 1, 2020
# 2020-12-11
# -----------------
# Mailbag: Blue Jackets' needs, rise of analytics in hockey
# NHL.com's Dan Rosen answers weekly questions
# 2020-12-16
# -----------------
# Marner says new veterans on Maple Leafs can 'keep us in line'
# Forward hopes additions of Thornton, Simmonds help end series-winning drought
# 2020-12-18
# -----------------
# Jagr gets assist in Czech Republic to start 33rd pro season
# 48-year-old former NHL forward playing for Kladno
# 2020-12-16
# -----------------
# Fantasy hockey top 250 player rankings
# NHL.com lists best overall options for standard leagues; season preview podcasts
# 2020-12-18
# -----------------
# 2021 World Junior Championship rosters
# Kings top NHL again with nine prospects; country, NHL affiliation for all participants
# 2020-12-14
# -----------------
# Pacioretty says Golden Knights trade rumors 'lightweight stuff': report
# Forward has three seasons remaining on four-year, $28 million contract
# 2020-12-18
# -----------------
# Stalock could miss start of training camp for Wild with upper-body injury
# Recovery time for goalie undetermined, Hammond signed to contract
# 2020-12-18
# -----------------
# Fantasy hockey top 25 goalie rankings
# Samsonov among 10 best options with Capitals; Kahkonen worth look from Wild
# 2020-12-17
# -----------------
# Dec. 19: NHL plays first games
# Plus: Gretzky fastest to 1,000 points; Bourque third defenseman to score 300 goals
# 2020-12-19

# %%
# Display the MongoDB records created above
articles = db.articles.find()
for article in articles:
    print(article)
# Out:
# {'_id': ObjectId('5ee7e54aadf691a8f760f84f'), 'header': '5 questions for Canadiens in Stanley Cup Qualifiers', 'subheader': 'Play of Price, Domi status among unknowns heading into best-of-5 series vs. Penguins', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee7e54aadf691a8f760f850'), 'header': 'Phase 2 Buzz: Holtby, Kuznetsov, Carlson on ice for Capitals', 'subheader': 'Farabee among Flyers who skated Monday; Krug, Bergeron, Marchand participate for Bruins', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee7e54aadf691a8f760f851'), 'header': "Draisaitl of Oilers should win Hart Trophy, Bruins' Pastrnak says", 'subheader': 'Edmonton forward led NHL in points; Boston right wing tied for most goals', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee7e54aadf691a8f760f852'), 'header': '5 questions for Blackhawks in Stanley Cup Qualifiers', 'subheader': 'Play of DeBrincat, Crawford among unknowns heading into best-of-5 series vs. Oilers', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee7e54aadf691a8f760f853'), 'header': '2004 NHL Redraft: Ovechkin, Malkin again top two picks', 'subheader': 'Krejci moves up 59 spots to No. 4; Rinne goes from eighth round to top five', 'date': '2020-06-13'}
# {'_id': ObjectId('5ee7e54aadf691a8f760f854'), 'header': 'NHL training camps for Stanley Cup Qualifiers to open July 10', 'subheader': 'Phase 3 of Return to Play Plan will occur if medical, safety conditions allow', 'date': '2020-06-11'}
# {'_id': ObjectId('5ee7e54aadf691a8f760f855'), 'header': "'NHL's Who Wore It Best?': Nos. 10-1", 'subheader': 'Howe, Orr, Plante among top vote-getters for his uniform number', 'date': '2020-06-12'}
# {'_id': ObjectId('5ee7e54aadf691a8f760f856'), 'header': 'Favorite playoff memory: Turco recalls four-OT game with Stars', 'subheader': 'Made 61 saves against Sharks to win eighth-longest game in NHL history', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee7e54aadf691a8f760f857'), 'header': 'Color of Hockey: NHLCA clinic provides steppingstone for black coaches', 'subheader': 'Weeklong gathering offers opportunities for learning, networking, mentoring', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee7e54aadf691a8f760f858'), 'header': 'Montreal Dragons league lets LGBTQ+ players be themselves', 'subheader': "Provides fun, safe, competitive atmosphere with 'no prejudice, no judgment'", 'date': '2020-06-15'}
# {'_id': ObjectId('5ee7e54aadf691a8f760f859'), 'header': 'Stanley Cup Playoffs to be best-of-7 following qualifiers', 'subheader': 'Seeding format, round-robin tiebreakers also announced', 'date': '2020-06-09'}
# {'_id': ObjectId('5ee7e54aadf691a8f760f85a'), 'header': 'Ducks honor Class of 2020 with graduation gifts outside Honda Center', 'subheader': 'Team hosts celebration for those whose commencement was postponed due to COVID-19 pandemic', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee7e54aadf691a8f760f85b'), 'header': 'McDavid, Rinne, Fleury and more win 2020 NHL Fan Choice Awards', 'subheader': 'There were more than a few tight races, but voting is finished and hockey fans have spoken', 'date': '2020-06-13'}
# {'_id': ObjectId('5ee7e54aadf691a8f760f85c'), 'header': 'Our Vision: Hockey Is Indeed For Everyone', 'subheader': 'We can, will do better, as a League, as a game', 'date': '2020-06-11'}
# {'_id': ObjectId('5ee7e54aadf691a8f760f85d'), 'header': 'Fantasy forward top 100 rankings for 2020 Stanley Cup', 'subheader': 'NHL.com lists best options at position for 24-team tournament; podcast analysis', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee7e54aadf691a8f760f85e'), 'header': 'NHL teams continue voluntary workouts as part of Phase 2', 'subheader': 'Several have opened facilities in next step of Return to Play Plan', 'date': '2020-06-12'}
# {'_id': ObjectId('5ee7e54aadf691a8f760f85f'), 'header': "Marner 'amazes me,' Marleau says of former Maple Leafs teammate", 'subheader': 'Forward has tools to be one of top players in NHL, according to Penguins veteran', 'date': '2020-06-13'}
# {'_id': ObjectId('5ee7e54aadf691a8f760f860'), 'header': 'Muller salutes Youppi! for Mascot Hall of Fame induction', 'subheader': 'Canadiens assistant coach sends well wishes to longtime Montreal mascot', 'date': '2020-06-14'}
# {'_id': ObjectId('5ee7e54aadf691a8f760f861'), 'header': 'Favorite playoff memory: Sharp recalls Game 5 with Blackhawks in 2010', 'subheader': "Byfuglien hit on Pronger, home crowd's energy established momentum in Cup Final", 'date': '2020-06-14'}
# {'_id': ObjectId('5ee7e54aadf691a8f760f862'), 'header': 'Super 16: Top goalies playing in Stanley Cup Qualifiers', 'subheader': 'Rask, Vasilevskiy among best in NHL.com ranking of those returning to play', 'date': '2020-06-11'}
# {'_id': ObjectId('5ee7e54aadf691a8f760f863'), 'header': 'NHL plans to return with 24 teams competing for Stanley Cup', 'subheader': 'Will begin with best-of-5 series, round-robin games in two hub cities; date not determined', 'date': '2020-06-09'}
# {'_id': ObjectId('5ee7e54aadf691a8f760f864'), 'header': 'Fantasy pool rankings for 2020 Stanley Cup', 'subheader': 'NHL.com lists top 100 overall players for 24-team tournament; podcast analysis', 'date': '2020-06-12'}
# {'_id': ObjectId('5ee7e54aadf691a8f760f865'), 'header': 'Blues mark anniversary of Stanley Cup win by saying they can repeat', 'subheader': "Pietrangelo expects 'success moving forward' in qualifiers, playoffs", 'date': '2020-06-12'}
# {'_id': ObjectId('5ee7e54aadf691a8f760f866'), 'header': 'Treliving nails incredible trick shot from rafters in support of AGM Snow', 'subheader': 'Flames GM helps raise awareness for ALS', 'date': '2020-06-13'}
# {'_id': ObjectId('5ee7e54aadf691a8f760f867'), 'header': "Canucks approaching Return to Play Plan as 'new season': report", 'subheader': 'Have used pause to work on changes in strategy, coach says', 'date': '2020-06-12'}
# {'_id': ObjectId('5ee7e54aadf691a8f760f868'), 'header': "Cave's wife, teammate create song 'Agape' to honor late player", 'subheader': 'Marody used audio of wedding vows as inspiration for musical tribute', 'date': '2020-06-12'}
# {'_id': ObjectId('5ee7e54aadf691a8f760f869'), 'header': 'Oshie launches COVID-19 Relief Auction to benefit D.C. hospital', 'subheader': 'A 30-minute video chat with Capitals forward and 10 friends one item up for bid', 'date': '2020-06-12'}
# {'_id': ObjectId('5ee7e54aadf691a8f760f86a'), 'header': 'Lamoriello crashes Islanders fan video call with Ledecky', 'subheader': 'Islanders GM jumps in, jokes around, answers questions from season ticket holders', 'date': '2020-06-12'}
# {'_id': ObjectId('5ee7e54aadf691a8f760f86b'), 'header': 'NHL Fantasy on Ice podcast available now', 'subheader': 'Fantasy pool rankings debate; ceiling of Flyers, Maple Leafs; guest: Alberga', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee7e54aadf691a8f760f86c'), 'header': 'June 15: Bruins win Cup for first time in 39 years', 'subheader': 'Plus: Ducks join NHL; Blackhawks top Lightning for third championship in six seasons', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee7e59cadf691a8f760f86e'), 'header': '5 questions for Canadiens in Stanley Cup Qualifiers', 'subheader': 'Play of Price, Domi status among unknowns heading into best-of-5 series vs. Penguins', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee7e59cadf691a8f760f86f'), 'header': 'Phase 2 Buzz: Holtby, Kuznetsov, Carlson on ice for Capitals', 'subheader': 'Farabee among Flyers who skated Monday; Krug, Bergeron, Marchand participate for Bruins', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee7e59cadf691a8f760f870'), 'header': "Draisaitl of Oilers should win Hart Trophy, Bruins' Pastrnak says", 'subheader': 'Edmonton forward led NHL in points; Boston right wing tied for most goals', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee7e59cadf691a8f760f871'), 'header': '5 questions for Blackhawks in Stanley Cup Qualifiers', 'subheader': 'Play of DeBrincat, Crawford among unknowns heading into best-of-5 series vs. Oilers', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee7e59cadf691a8f760f872'), 'header': '2004 NHL Redraft: Ovechkin, Malkin again top two picks', 'subheader': 'Krejci moves up 59 spots to No. 4; Rinne goes from eighth round to top five', 'date': '2020-06-13'}
# {'_id': ObjectId('5ee7e59cadf691a8f760f873'), 'header': 'NHL training camps for Stanley Cup Qualifiers to open July 10', 'subheader': 'Phase 3 of Return to Play Plan will occur if medical, safety conditions allow', 'date': '2020-06-11'}
# {'_id': ObjectId('5ee7e59cadf691a8f760f874'), 'header': "'NHL's Who Wore It Best?': Nos. 10-1", 'subheader': 'Howe, Orr, Plante among top vote-getters for his uniform number', 'date': '2020-06-12'}
# {'_id': ObjectId('5ee7e59cadf691a8f760f875'), 'header': 'Favorite playoff memory: Turco recalls four-OT game with Stars', 'subheader': 'Made 61 saves against Sharks to win eighth-longest game in NHL history', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee7e59cadf691a8f760f876'), 'header': 'Color of Hockey: NHLCA clinic provides steppingstone for black coaches', 'subheader': 'Weeklong gathering offers opportunities for learning, networking, mentoring', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee7e59cadf691a8f760f877'), 'header': 'Montreal Dragons league lets LGBTQ+ players be themselves', 'subheader': "Provides fun, safe, competitive atmosphere with 'no prejudice, no judgment'", 'date': '2020-06-15'}
# {'_id': ObjectId('5ee7e59cadf691a8f760f878'), 'header': 'Stanley Cup Playoffs to be best-of-7 following qualifiers', 'subheader': 'Seeding format, round-robin tiebreakers also announced', 'date': '2020-06-09'}
# {'_id': ObjectId('5ee7e59cadf691a8f760f879'), 'header': 'Ducks honor Class of 2020 with graduation gifts outside Honda Center', 'subheader': 'Team hosts celebration for those whose commencement was postponed due to COVID-19 pandemic', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee7e59cadf691a8f760f87a'), 'header': 'McDavid, Rinne, Fleury and more win 2020 NHL Fan Choice Awards', 'subheader': 'There were more than a few tight races, but voting is finished and hockey fans have spoken', 'date': '2020-06-13'}
# {'_id': ObjectId('5ee7e59cadf691a8f760f87b'), 'header': 'Our Vision: Hockey Is Indeed For Everyone', 'subheader': 'We can, will do better, as a League, as a game', 'date': '2020-06-11'}
# {'_id': ObjectId('5ee7e59cadf691a8f760f87c'), 'header': 'Fantasy forward top 100 rankings for 2020 Stanley Cup', 'subheader': 'NHL.com lists best options at position for 24-team tournament; podcast analysis', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee7e59cadf691a8f760f87d'), 'header': 'NHL teams continue voluntary workouts as part of Phase 2', 'subheader': 'Several have opened facilities in next step of Return to Play Plan', 'date': '2020-06-12'}
# {'_id': ObjectId('5ee7e59cadf691a8f760f87e'), 'header': "Marner 'amazes me,' Marleau says of former Maple Leafs teammate", 'subheader': 'Forward has tools to be one of top players in NHL, according to Penguins veteran', 'date': '2020-06-13'}
# {'_id': ObjectId('5ee7e59cadf691a8f760f87f'), 'header': 'Muller salutes Youppi! for Mascot Hall of Fame induction', 'subheader': 'Canadiens assistant coach sends well wishes to longtime Montreal mascot', 'date': '2020-06-14'}
# {'_id': ObjectId('5ee7e59cadf691a8f760f880'), 'header': 'Favorite playoff memory: Sharp recalls Game 5 with Blackhawks in 2010', 'subheader': "Byfuglien hit on Pronger, home crowd's energy established momentum in Cup Final", 'date': '2020-06-14'}
# {'_id': ObjectId('5ee7e59cadf691a8f760f881'), 'header': 'Super 16: Top goalies playing in Stanley Cup Qualifiers', 'subheader': 'Rask, Vasilevskiy among best in NHL.com ranking of those returning to play', 'date': '2020-06-11'}
# {'_id': ObjectId('5ee7e59cadf691a8f760f882'), 'header': 'NHL plans to return with 24 teams competing for Stanley Cup', 'subheader': 'Will begin with best-of-5 series, round-robin games in two hub cities; date not determined', 'date': '2020-06-09'}
# {'_id': ObjectId('5ee7e59cadf691a8f760f883'), 'header': 'Fantasy pool rankings for 2020 Stanley Cup', 'subheader': 'NHL.com lists top 100 overall players for 24-team tournament; podcast analysis', 'date': '2020-06-12'}
# {'_id': ObjectId('5ee7e59cadf691a8f760f884'), 'header': 'Blues mark anniversary of Stanley Cup win by saying they can repeat', 'subheader': "Pietrangelo expects 'success moving forward' in qualifiers, playoffs", 'date': '2020-06-12'}
# {'_id': ObjectId('5ee7e59cadf691a8f760f885'), 'header': 'Treliving nails incredible trick shot from rafters in support of AGM Snow', 'subheader': 'Flames GM helps raise awareness for ALS', 'date': '2020-06-13'}
# {'_id': ObjectId('5ee7e59cadf691a8f760f886'), 'header': "Canucks approaching Return to Play Plan as 'new season': report", 'subheader': 'Have used pause to work on changes in strategy, coach says', 'date': '2020-06-12'}
# {'_id': ObjectId('5ee7e59cadf691a8f760f887'), 'header': "Cave's wife, teammate create song 'Agape' to honor late player", 'subheader': 'Marody used audio of wedding vows as inspiration for musical tribute', 'date': '2020-06-12'}
# {'_id': ObjectId('5ee7e59cadf691a8f760f888'), 'header': 'Oshie launches COVID-19 Relief Auction to benefit D.C. hospital', 'subheader': 'A 30-minute video chat with Capitals forward and 10 friends one item up for bid', 'date': '2020-06-12'}
# {'_id': ObjectId('5ee7e59cadf691a8f760f889'), 'header': 'Lamoriello crashes Islanders fan video call with Ledecky', 'subheader': 'Islanders GM jumps in, jokes around, answers questions from season ticket holders', 'date': '2020-06-12'}
# {'_id': ObjectId('5ee7e59cadf691a8f760f88a'), 'header': 'NHL Fantasy on Ice podcast available now', 'subheader': 'Fantasy pool rankings debate; ceiling of Flyers, Maple Leafs; guest: Alberga', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee7e59cadf691a8f760f88b'), 'header': 'June 15: Bruins win Cup for first time in 39 years', 'subheader': 'Plus: Ducks join NHL; Blackhawks top Lightning for third championship in six seasons', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee7e647adf691a8f760f88d'), 'header': '5 questions for Canadiens in Stanley Cup Qualifiers', 'subheader': 'Play of Price, Domi status among unknowns heading into best-of-5 series vs. Penguins', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee7e647adf691a8f760f88e'), 'header': 'Phase 2 Buzz: Holtby, Kuznetsov, Carlson on ice for Capitals', 'subheader': 'Farabee among Flyers who skated Monday; Krug, Bergeron, Marchand participate for Bruins', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee7e647adf691a8f760f88f'), 'header': "Draisaitl of Oilers should win Hart Trophy, Bruins' Pastrnak says", 'subheader': 'Edmonton forward led NHL in points; Boston right wing tied for most goals', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee7e647adf691a8f760f890'), 'header': '5 questions for Blackhawks in Stanley Cup Qualifiers', 'subheader': 'Play of DeBrincat, Crawford among unknowns heading into best-of-5 series vs. Oilers', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee7e647adf691a8f760f891'), 'header': '2004 NHL Redraft: Ovechkin, Malkin again top two picks', 'subheader': 'Krejci moves up 59 spots to No. 4; Rinne goes from eighth round to top five', 'date': '2020-06-13'}
# {'_id': ObjectId('5ee7e647adf691a8f760f892'), 'header': 'NHL training camps for Stanley Cup Qualifiers to open July 10', 'subheader': 'Phase 3 of Return to Play Plan will occur if medical, safety conditions allow', 'date': '2020-06-11'}
# {'_id': ObjectId('5ee7e647adf691a8f760f893'), 'header': "'NHL's Who Wore It Best?': Nos. 10-1", 'subheader': 'Howe, Orr, Plante among top vote-getters for his uniform number', 'date': '2020-06-12'}
# {'_id': ObjectId('5ee7e647adf691a8f760f894'), 'header': 'Favorite playoff memory: Turco recalls four-OT game with Stars', 'subheader': 'Made 61 saves against Sharks to win eighth-longest game in NHL history', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee7e647adf691a8f760f895'), 'header': 'Color of Hockey: NHLCA clinic provides steppingstone for black coaches', 'subheader': 'Weeklong gathering offers opportunities for learning, networking, mentoring', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee7e647adf691a8f760f896'), 'header': 'Montreal Dragons league lets LGBTQ+ players be themselves', 'subheader': "Provides fun, safe, competitive atmosphere with 'no prejudice, no judgment'", 'date': '2020-06-15'}
# {'_id': ObjectId('5ee7e647adf691a8f760f897'), 'header': 'Stanley Cup Playoffs to be best-of-7 following qualifiers', 'subheader': 'Seeding format, round-robin tiebreakers also announced', 'date': '2020-06-09'}
# {'_id': ObjectId('5ee7e647adf691a8f760f898'), 'header': 'Ducks honor Class of 2020 with graduation gifts outside Honda Center', 'subheader': 'Team hosts celebration for those whose commencement was postponed due to COVID-19 pandemic', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee7e647adf691a8f760f899'), 'header': 'McDavid, Rinne, Fleury and more win 2020 NHL Fan Choice Awards', 'subheader': 'There were more than a few tight races, but voting is finished and hockey fans have spoken', 'date': '2020-06-13'}
# {'_id': ObjectId('5ee7e647adf691a8f760f89a'), 'header': 'Our Vision: Hockey Is Indeed For Everyone', 'subheader': 'We can, will do better, as a League, as a game', 'date': '2020-06-11'}
# {'_id': ObjectId('5ee7e647adf691a8f760f89b'), 'header': 'Fantasy forward top 100 rankings for 2020 Stanley Cup', 'subheader': 'NHL.com lists best options at position for 24-team tournament; podcast analysis', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee7e647adf691a8f760f89c'), 'header': 'NHL teams continue voluntary workouts as part of Phase 2', 'subheader': 'Several have opened facilities in next step of Return to Play Plan', 'date': '2020-06-12'}
# {'_id': ObjectId('5ee7e647adf691a8f760f89d'), 'header': "Marner 'amazes me,' Marleau says of former Maple Leafs teammate", 'subheader': 'Forward has tools to be one of top players in NHL, according to Penguins veteran', 'date': '2020-06-13'}
# {'_id': ObjectId('5ee7e647adf691a8f760f89e'), 'header': 'Muller salutes Youppi! for Mascot Hall of Fame induction', 'subheader': 'Canadiens assistant coach sends well wishes to longtime Montreal mascot', 'date': '2020-06-14'}
# {'_id': ObjectId('5ee7e647adf691a8f760f89f'), 'header': 'Favorite playoff memory: Sharp recalls Game 5 with Blackhawks in 2010', 'subheader': "Byfuglien hit on Pronger, home crowd's energy established momentum in Cup Final", 'date': '2020-06-14'}
# {'_id': ObjectId('5ee7e647adf691a8f760f8a0'), 'header': 'Super 16: Top goalies playing in Stanley Cup Qualifiers', 'subheader': 'Rask, Vasilevskiy among best in NHL.com ranking of those returning to play', 'date': '2020-06-11'}
# {'_id': ObjectId('5ee7e647adf691a8f760f8a1'), 'header': 'NHL plans to return with 24 teams competing for Stanley Cup', 'subheader': 'Will begin with best-of-5 series, round-robin games in two hub cities; date not determined', 'date': '2020-06-09'}
# {'_id': ObjectId('5ee7e647adf691a8f760f8a2'), 'header': 'Fantasy pool rankings for 2020 Stanley Cup', 'subheader': 'NHL.com lists top 100 overall players for 24-team tournament; podcast analysis', 'date': '2020-06-12'}
# {'_id': ObjectId('5ee7e647adf691a8f760f8a3'), 'header': 'Blues mark anniversary of Stanley Cup win by saying they can repeat', 'subheader': "Pietrangelo expects 'success moving forward' in qualifiers, playoffs", 'date': '2020-06-12'}
# {'_id': ObjectId('5ee7e647adf691a8f760f8a4'), 'header': 'Treliving nails incredible trick shot from rafters in support of AGM Snow', 'subheader': 'Flames GM helps raise awareness for ALS', 'date': '2020-06-13'}
# {'_id': ObjectId('5ee7e647adf691a8f760f8a5'), 'header': "Canucks approaching Return to Play Plan as 'new season': report", 'subheader': 'Have used pause to work on changes in strategy, coach says', 'date': '2020-06-12'}
# {'_id': ObjectId('5ee7e647adf691a8f760f8a6'), 'header': "Cave's wife, teammate create song 'Agape' to honor late player", 'subheader': 'Marody used audio of wedding vows as inspiration for musical tribute', 'date': '2020-06-12'}
# {'_id': ObjectId('5ee7e647adf691a8f760f8a7'), 'header': 'Oshie launches COVID-19 Relief Auction to benefit D.C. hospital', 'subheader': 'A 30-minute video chat with Capitals forward and 10 friends one item up for bid', 'date': '2020-06-12'}
# {'_id': ObjectId('5ee7e647adf691a8f760f8a8'), 'header': 'Lamoriello crashes Islanders fan video call with Ledecky', 'subheader': 'Islanders GM jumps in, jokes around, answers questions from season ticket holders', 'date': '2020-06-12'}
# {'_id': ObjectId('5ee7e647adf691a8f760f8a9'), 'header': 'NHL Fantasy on Ice podcast available now', 'subheader': 'Fantasy pool rankings debate; ceiling of Flyers, Maple Leafs; guest: Alberga', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee7e647adf691a8f760f8aa'), 'header': 'June 15: Bruins win Cup for first time in 39 years', 'subheader': 'Plus: Ducks join NHL; Blackhawks top Lightning for third championship in six seasons', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee81d07dcec0218ff73233f'), 'header': '5 questions for Canadiens in Stanley Cup Qualifiers', 'subheader': 'Play of Price, Domi status among unknowns heading into best-of-5 series vs. Penguins', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee81d07dcec0218ff732340'), 'header': 'Ovechkin could rejoin Capitals in near future, Reirden says', 'subheader': "Forward has been training in Florida during pause, in a 'really good spot mentally and physically'", 'date': '2020-06-15'}
# {'_id': ObjectId('5ee81d07dcec0218ff732341'), 'header': "Draisaitl of Oilers should win Hart Trophy, Bruins' Pastrnak says", 'subheader': 'Edmonton forward led NHL in points; Boston right wing tied for most goals', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee81d07dcec0218ff732342'), 'header': 'Phase 2 Buzz: Holtby, Kuznetsov, Carlson on ice for Capitals', 'subheader': 'Farabee among Flyers who skated Monday; Krug, Bergeron, Marchand participate for Bruins', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee81d07dcec0218ff732343'), 'header': 'Bettman to discuss NHL Return to Play Plan on ESPN program', 'subheader': "Will be one of six commissioners on 'The Return of Sports'", 'date': '2020-06-15'}
# {'_id': ObjectId('5ee81d07dcec0218ff732344'), 'header': 'NHL training camps for Stanley Cup Qualifiers to open July 10', 'subheader': 'Phase 3 of Return to Play Plan will occur if medical, safety conditions allow', 'date': '2020-06-11'}
# {'_id': ObjectId('5ee81d07dcec0218ff732345'), 'header': 'Gritty attends socially distant kindergarten graduation', 'subheader': 'Flyers mascot leads kids in dances, games while wearing protective face shield', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee81d07dcec0218ff732346'), 'header': 'NHL season will resume at high level of play, Golden Knights GM says', 'subheader': 'Expects players to be healthier, fresher than usual after pause', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee81d07dcec0218ff732347'), 'header': '5 questions for Blackhawks in Stanley Cup Qualifiers', 'subheader': 'Play of DeBrincat, Crawford among unknowns heading into best-of-5 series vs. Oilers', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee81d07dcec0218ff732348'), 'header': 'Reaves signs two-year, $3.5 million contract with Golden Knights', 'subheader': 'Forward could have been unrestricted free agent after season', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee81d07dcec0218ff732349'), 'header': 'Stanley Cup Playoffs to be best-of-7 following qualifiers', 'subheader': 'Seeding format, round-robin tiebreakers also announced', 'date': '2020-06-09'}
# {'_id': ObjectId('5ee81d07dcec0218ff73234a'), 'header': '2004 NHL Redraft: Ovechkin, Malkin again top two picks', 'subheader': 'Krejci moves up 59 spots to No. 4; Rinne goes from eighth round to top five', 'date': '2020-06-13'}
# {'_id': ObjectId('5ee81d07dcec0218ff73234b'), 'header': 'Greatest Moments of the NHL Season … So Far reaches final four', 'subheader': 'Ayres to face Svechnikov, Rinne against Fleury in fan voting next week', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee81d07dcec0218ff73234c'), 'header': "'NHL's Who Wore It Best?': Nos. 10-1", 'subheader': 'Howe, Orr, Plante among top vote-getters for his uniform number', 'date': '2020-06-12'}
# {'_id': ObjectId('5ee81d07dcec0218ff73234d'), 'header': 'Fantasy forward top 100 rankings for 2020 Stanley Cup', 'subheader': 'NHL.com lists best options at position for 24-team tournament; podcast analysis', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee81d07dcec0218ff73234e'), 'header': 'NHL teams continue voluntary workouts as part of Phase 2', 'subheader': 'Several have opened facilities in next step of Return to Play Plan', 'date': '2020-06-12'}
# {'_id': ObjectId('5ee81d07dcec0218ff73234f'), 'header': 'Favorite playoff memory: Turco recalls four-OT game with Stars', 'subheader': 'Made 61 saves against Sharks to win eighth-longest game in NHL history', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee81d07dcec0218ff732350'), 'header': 'Color of Hockey: NHLCA clinic provides steppingstone for black coaches', 'subheader': 'Weeklong gathering offers opportunities for learning, networking, mentoring', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee81d07dcec0218ff732351'), 'header': 'Montreal Dragons league lets LGBTQ+ players be themselves', 'subheader': "Provides fun, safe, competitive atmosphere with 'no prejudice, no judgment'", 'date': '2020-06-15'}
# {'_id': ObjectId('5ee81d07dcec0218ff732352'), 'header': 'Ducks honor Class of 2020 with graduation gifts outside Honda Center', 'subheader': 'Team hosts celebration for those whose commencement was postponed due to COVID-19 pandemic', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee81d07dcec0218ff732353'), 'header': 'NHL plans to return with 24 teams competing for Stanley Cup', 'subheader': 'Will begin with best-of-5 series, round-robin games in two hub cities; date not determined', 'date': '2020-06-09'}
# {'_id': ObjectId('5ee81d07dcec0218ff732354'), 'header': 'Fantasy pool rankings for 2020 Stanley Cup', 'subheader': 'NHL.com lists top 100 overall players for 24-team tournament; podcast analysis', 'date': '2020-06-12'}
# {'_id': ObjectId('5ee81d07dcec0218ff732355'), 'header': 'Reaves announces some lofty goals after re-signing with Golden Knights', 'subheader': 'Forward is pumped to stay in Vegas, ready to make up 95-point gap to win scoring title', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee81d07dcec0218ff732356'), 'header': 'Six NHL executives part of AHL 2020-21 Return to Play task force', 'subheader': 'Will provide leadership, help identify opportunities for process acceptable to each league', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee81d07dcec0218ff732357'), 'header': 'McDavid, Rinne, Fleury and more win 2020 NHL Fan Choice Awards', 'subheader': 'There were more than a few tight races, but voting is finished and hockey fans have spoken', 'date': '2020-06-13'}
# {'_id': ObjectId('5ee81d07dcec0218ff732358'), 'header': 'Our Vision: Hockey Is Indeed For Everyone', 'subheader': 'We can, will do better, as a League, as a game', 'date': '2020-06-11'}
# {'_id': ObjectId('5ee81d07dcec0218ff732359'), 'header': 'Super 16: Top goalies playing in Stanley Cup Qualifiers', 'subheader': 'Rask, Vasilevskiy among best in NHL.com ranking of those returning to play', 'date': '2020-06-11'}
# {'_id': ObjectId('5ee81d07dcec0218ff73235a'), 'header': "Marner 'amazes me,' Marleau says of former Maple Leafs teammate", 'subheader': 'Forward has tools to be one of top players in NHL, according to Penguins veteran', 'date': '2020-06-13'}
# {'_id': ObjectId('5ee81d07dcec0218ff73235b'), 'header': 'NHL Fantasy on Ice podcast available now', 'subheader': 'Fantasy pool rankings debate; ceiling of Flyers, Maple Leafs; guest: Alberga', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee81d07dcec0218ff73235c'), 'header': 'June 15: Bruins win Cup for first time in 39 years', 'subheader': 'Plus: Ducks join NHL; Blackhawks top Lightning for third championship in six seasons', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee82226dcec0218ff73235e'), 'header': '5 questions for Canadiens in Stanley Cup Qualifiers', 'subheader': 'Play of Price, Domi status among unknowns heading into best-of-5 series vs. Penguins', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee82226dcec0218ff73235f'), 'header': 'Ovechkin could rejoin Capitals in near future, Reirden says', 'subheader': "Forward has been training in Florida during pause, in a 'really good spot mentally and physically'", 'date': '2020-06-15'}
# {'_id': ObjectId('5ee82226dcec0218ff732360'), 'header': "Draisaitl of Oilers should win Hart Trophy, Bruins' Pastrnak says", 'subheader': 'Edmonton forward led NHL in points; Boston right wing tied for most goals', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee82226dcec0218ff732361'), 'header': 'Phase 2 Buzz: Holtby, Kuznetsov, Carlson on ice for Capitals', 'subheader': 'Farabee among Flyers who skated Monday; Krug, Bergeron, Marchand participate for Bruins', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee82226dcec0218ff732362'), 'header': 'Gritty attends socially distant kindergarten graduation', 'subheader': 'Flyers mascot leads kids in dances, games while wearing protective face shield', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee82226dcec0218ff732363'), 'header': 'NHL training camps for Stanley Cup Qualifiers to open July 10', 'subheader': 'Phase 3 of Return to Play Plan will occur if medical, safety conditions allow', 'date': '2020-06-11'}
# {'_id': ObjectId('5ee82226dcec0218ff732364'), 'header': 'NHL season will resume at high level of play, Golden Knights GM says', 'subheader': 'Expects players to be healthier, fresher than usual after pause', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee82226dcec0218ff732365'), 'header': '5 questions for Blackhawks in Stanley Cup Qualifiers', 'subheader': 'Play of DeBrincat, Crawford among unknowns heading into best-of-5 series vs. Oilers', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee82226dcec0218ff732366'), 'header': 'Reaves signs two-year, $3.5 million contract with Golden Knights', 'subheader': 'Forward could have been unrestricted free agent after season', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee82226dcec0218ff732367'), 'header': '2004 NHL Redraft: Ovechkin, Malkin again top two picks', 'subheader': 'Krejci moves up 59 spots to No. 4; Rinne goes from eighth round to top five', 'date': '2020-06-13'}
# {'_id': ObjectId('5ee82226dcec0218ff732368'), 'header': 'Stanley Cup Playoffs to be best-of-7 following qualifiers', 'subheader': 'Seeding format, round-robin tiebreakers also announced', 'date': '2020-06-09'}
# {'_id': ObjectId('5ee82226dcec0218ff732369'), 'header': 'Greatest Moments of the NHL Season … So Far reaches final four', 'subheader': 'Ayres to face Svechnikov, Rinne against Fleury in fan voting next week', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee82226dcec0218ff73236a'), 'header': "'NHL's Who Wore It Best?': Nos. 10-1", 'subheader': 'Howe, Orr, Plante among top vote-getters for his uniform number', 'date': '2020-06-12'}
# {'_id': ObjectId('5ee82226dcec0218ff73236b'), 'header': 'Favorite playoff memory: Turco recalls four-OT game with Stars', 'subheader': 'Made 61 saves against Sharks to win eighth-longest game in NHL history', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee82226dcec0218ff73236c'), 'header': 'Fantasy forward top 100 rankings for 2020 Stanley Cup', 'subheader': 'NHL.com lists best options at position for 24-team tournament; podcast analysis', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee82226dcec0218ff73236d'), 'header': 'NHL teams continue voluntary workouts as part of Phase 2', 'subheader': 'Several have opened facilities in next step of Return to Play Plan', 'date': '2020-06-12'}
# {'_id': ObjectId('5ee82226dcec0218ff73236e'), 'header': 'Color of Hockey: NHLCA clinic provides steppingstone for black coaches', 'subheader': 'Weeklong gathering offers opportunities for learning, networking, mentoring', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee82226dcec0218ff73236f'), 'header': 'Montreal Dragons league lets LGBTQ+ players be themselves', 'subheader': "Provides fun, safe, competitive atmosphere with 'no prejudice, no judgment'", 'date': '2020-06-15'}
# {'_id': ObjectId('5ee82226dcec0218ff732370'), 'header': 'Ducks honor Class of 2020 with graduation gifts outside Honda Center', 'subheader': 'Team hosts celebration for those whose commencement was postponed due to COVID-19 pandemic', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee82226dcec0218ff732371'), 'header': 'Reaves announces some lofty goals after re-signing with Golden Knights', 'subheader': 'Forward is pumped to stay in Vegas, ready to make up 95-point gap to win scoring title', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee82226dcec0218ff732372'), 'header': 'NHL plans to return with 24 teams competing for Stanley Cup', 'subheader': 'Will begin with best-of-5 series, round-robin games in two hub cities; date not determined', 'date': '2020-06-09'}
# {'_id': ObjectId('5ee82226dcec0218ff732373'), 'header': 'Fantasy pool rankings for 2020 Stanley Cup', 'subheader': 'NHL.com lists top 100 overall players for 24-team tournament; podcast analysis', 'date': '2020-06-12'}
# {'_id': ObjectId('5ee82226dcec0218ff732374'), 'header': 'Six NHL executives part of AHL 2020-21 Return to Play task force', 'subheader': 'Will provide leadership, help identify opportunities for process acceptable to each league', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee82226dcec0218ff732375'), 'header': 'McDavid, Rinne, Fleury and more win 2020 NHL Fan Choice Awards', 'subheader': 'There were more than a few tight races, but voting is finished and hockey fans have spoken', 'date': '2020-06-13'}
# {'_id': ObjectId('5ee82226dcec0218ff732376'), 'header': 'Our Vision: Hockey Is Indeed For Everyone', 'subheader': 'We can, will do better, as a League, as a game', 'date': '2020-06-11'}
# {'_id': ObjectId('5ee82226dcec0218ff732377'), 'header': 'Super 16: Top goalies playing in Stanley Cup Qualifiers', 'subheader': 'Rask, Vasilevskiy among best in NHL.com ranking of those returning to play', 'date': '2020-06-11'}
# {'_id': ObjectId('5ee82226dcec0218ff732378'), 'header': "Marner 'amazes me,' Marleau says of former Maple Leafs teammate", 'subheader': 'Forward has tools to be one of top players in NHL, according to Penguins veteran', 'date': '2020-06-13'}
# {'_id': ObjectId('5ee82226dcec0218ff732379'), 'header': 'NHL Fantasy on Ice podcast available now', 'subheader': 'Fantasy pool rankings debate; ceiling of Flyers, Maple Leafs; guest: Alberga', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee82226dcec0218ff73237a'), 'header': 'June 15: Bruins win Cup for first time in 39 years', 'subheader': 'Plus: Ducks join NHL; Blackhawks top Lightning for third championship in six seasons', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee8236ddcec0218ff73237b'), 'header': '5 questions for Canadiens in Stanley Cup Qualifiers', 'subheader': 'Play of Price, Domi status among unknowns heading into best-of-5 series vs. Penguins', 'date': ''}
# {'_id': ObjectId('5ee8236ddcec0218ff73237c'), 'header': 'Ovechkin could rejoin Capitals in near future, Reirden says', 'subheader': "Forward has been training in Florida during pause, in a 'really good spot mentally and physically'", 'date': ''}
# {'_id': ObjectId('5ee8236ddcec0218ff73237d'), 'header': "Draisaitl of Oilers should win Hart Trophy, Bruins' Pastrnak says", 'subheader': 'Edmonton forward led NHL in points; Boston right wing tied for most goals', 'date': ''}
# {'_id': ObjectId('5ee8236ddcec0218ff73237e'), 'header': 'Phase 2 Buzz: Holtby, Kuznetsov, Carlson on ice for Capitals', 'subheader': 'Farabee among Flyers who skated Monday; Krug, Bergeron, Marchand participate for Bruins', 'date': ''}
# {'_id': ObjectId('5ee8236ddcec0218ff73237f'), 'header': 'Gritty attends socially distant kindergarten graduation', 'subheader': 'Flyers mascot leads kids in dances, games while wearing protective face shield', 'date': ''}
# {'_id': ObjectId('5ee8236ddcec0218ff732380'), 'header': 'NHL training camps for Stanley Cup Qualifiers to open July 10', 'subheader': 'Phase 3 of Return to Play Plan will occur if medical, safety conditions allow', 'date': ''}
# {'_id': ObjectId('5ee8236ddcec0218ff732381'), 'header': 'NHL season will resume at high level of play, Golden Knights GM says', 'subheader': 'Expects players to be healthier, fresher than usual after pause', 'date': ''}
# {'_id': ObjectId('5ee8236ddcec0218ff732382'), 'header': '5 questions for Blackhawks in Stanley Cup Qualifiers', 'subheader': 'Play of DeBrincat, Crawford among unknowns heading into best-of-5 series vs. Oilers', 'date': ''}
# {'_id': ObjectId('5ee8236ddcec0218ff732383'), 'header': 'Reaves signs two-year, $3.5 million contract with Golden Knights', 'subheader': 'Forward could have been unrestricted free agent after season', 'date': ''}
# {'_id': ObjectId('5ee8236ddcec0218ff732384'), 'header': '2004 NHL Redraft: Ovechkin, Malkin again top two picks', 'subheader': 'Krejci moves up 59 spots to No. 4; Rinne goes from eighth round to top five', 'date': ''}
# {'_id': ObjectId('5ee8236ddcec0218ff732385'), 'header': 'Stanley Cup Playoffs to be best-of-7 following qualifiers', 'subheader': 'Seeding format, round-robin tiebreakers also announced', 'date': ''}
# {'_id': ObjectId('5ee8236ddcec0218ff732386'), 'header': 'Greatest Moments of the NHL Season … So Far reaches final four', 'subheader': 'Ayres to face Svechnikov, Rinne against Fleury in fan voting next week', 'date': ''}
# {'_id': ObjectId('5ee8236ddcec0218ff732387'), 'header': "'NHL's Who Wore It Best?': Nos. 10-1", 'subheader': 'Howe, Orr, Plante among top vote-getters for his uniform number', 'date': ''}
# {'_id': ObjectId('5ee8236ddcec0218ff732388'), 'header': 'Favorite playoff memory: Turco recalls four-OT game with Stars', 'subheader': 'Made 61 saves against Sharks to win eighth-longest game in NHL history', 'date': ''}
# {'_id': ObjectId('5ee8236ddcec0218ff732389'), 'header': 'Fantasy forward top 100 rankings for 2020 Stanley Cup', 'subheader': 'NHL.com lists best options at position for 24-team tournament; podcast analysis', 'date': ''}
# {'_id': ObjectId('5ee8236ddcec0218ff73238a'), 'header': 'NHL teams continue voluntary workouts as part of Phase 2', 'subheader': 'Several have opened facilities in next step of Return to Play Plan', 'date': ''}
# {'_id': ObjectId('5ee8236ddcec0218ff73238b'), 'header': 'Color of Hockey: NHLCA clinic provides steppingstone for black coaches', 'subheader': 'Weeklong gathering offers opportunities for learning, networking, mentoring', 'date': ''}
# {'_id': ObjectId('5ee8236ddcec0218ff73238c'), 'header': 'Montreal Dragons league lets LGBTQ+ players be themselves', 'subheader': "Provides fun, safe, competitive atmosphere with 'no prejudice, no judgment'", 'date': ''}
# {'_id': ObjectId('5ee8236ddcec0218ff73238d'), 'header': 'Ducks honor Class of 2020 with graduation gifts outside Honda Center', 'subheader': 'Team hosts celebration for those whose commencement was postponed due to COVID-19 pandemic', 'date': ''}
# {'_id': ObjectId('5ee8236edcec0218ff73238e'), 'header': 'Reaves announces some lofty goals after re-signing with Golden Knights', 'subheader': 'Forward is pumped to stay in Vegas, ready to make up 95-point gap to win scoring title', 'date': ''}
# {'_id': ObjectId('5ee8236edcec0218ff73238f'), 'header': 'NHL plans to return with 24 teams competing for Stanley Cup', 'subheader': 'Will begin with best-of-5 series, round-robin games in two hub cities; date not determined', 'date': ''}
# {'_id': ObjectId('5ee8236edcec0218ff732390'), 'header': 'Fantasy pool rankings for 2020 Stanley Cup', 'subheader': 'NHL.com lists top 100 overall players for 24-team tournament; podcast analysis', 'date': ''}
# {'_id': ObjectId('5ee8236edcec0218ff732391'), 'header': 'Six NHL executives part of AHL 2020-21 Return to Play task force', 'subheader': 'Will provide leadership, help identify opportunities for process acceptable to each league', 'date': ''}
# {'_id': ObjectId('5ee8236edcec0218ff732392'), 'header': 'McDavid, Rinne, Fleury and more win 2020 NHL Fan Choice Awards', 'subheader': 'There were more than a few tight races, but voting is finished and hockey fans have spoken', 'date': ''}
# {'_id': ObjectId('5ee8236edcec0218ff732393'), 'header': 'Our Vision: Hockey Is Indeed For Everyone', 'subheader': 'We can, will do better, as a League, as a game', 'date': ''}
# {'_id': ObjectId('5ee8236edcec0218ff732394'), 'header': 'Super 16: Top goalies playing in Stanley Cup Qualifiers', 'subheader': 'Rask, Vasilevskiy among best in NHL.com ranking of those returning to play', 'date': ''}
# {'_id': ObjectId('5ee8236edcec0218ff732395'), 'header': "Marner 'amazes me,' Marleau says of former Maple Leafs teammate", 'subheader': 'Forward has tools to be one of top players in NHL, according to Penguins veteran', 'date': ''}
# {'_id': ObjectId('5ee8236edcec0218ff732396'), 'header': 'NHL Fantasy on Ice podcast available now', 'subheader': 'Fantasy pool rankings debate; ceiling of Flyers, Maple Leafs; guest: Alberga', 'date': ''}
# {'_id': ObjectId('5ee8236edcec0218ff732397'), 'header': 'June 15: Bruins win Cup for first time in 39 years', 'subheader': 'Plus: Ducks join NHL; Blackhawks top Lightning for third championship in six seasons', 'date': ''}
# {'_id': ObjectId('5ee8237bdcec0218ff732398'), 'header': '5 questions for Canadiens in Stanley Cup Qualifiers', 'subheader': 'Play of Price, Domi status among unknowns heading into best-of-5 series vs. Penguins', 'date': ''}
# {'_id': ObjectId('5ee8237bdcec0218ff732399'), 'header': 'Ovechkin could rejoin Capitals in near future, Reirden says', 'subheader': "Forward has been training in Florida during pause, in a 'really good spot mentally and physically'", 'date': ''}
# {'_id': ObjectId('5ee8237bdcec0218ff73239a'), 'header': "Draisaitl of Oilers should win Hart Trophy, Bruins' Pastrnak says", 'subheader': 'Edmonton forward led NHL in points; Boston right wing tied for most goals', 'date': ''}
# {'_id': ObjectId('5ee8237bdcec0218ff73239b'), 'header': 'Phase 2 Buzz: Holtby, Kuznetsov, Carlson on ice for Capitals', 'subheader': 'Farabee among Flyers who skated Monday; Krug, Bergeron, Marchand participate for Bruins', 'date': ''}
# {'_id': ObjectId('5ee8237bdcec0218ff73239c'), 'header': 'Gritty attends socially distant kindergarten graduation', 'subheader': 'Flyers mascot leads kids in dances, games while wearing protective face shield', 'date': ''}
# {'_id': ObjectId('5ee8237bdcec0218ff73239d'), 'header': 'NHL training camps for Stanley Cup Qualifiers to open July 10', 'subheader': 'Phase 3 of Return to Play Plan will occur if medical, safety conditions allow', 'date': ''}
# {'_id': ObjectId('5ee8237bdcec0218ff73239e'), 'header': 'NHL season will resume at high level of play, Golden Knights GM says', 'subheader': 'Expects players to be healthier, fresher than usual after pause', 'date': ''}
# {'_id': ObjectId('5ee8237bdcec0218ff73239f'), 'header': '5 questions for Blackhawks in Stanley Cup Qualifiers', 'subheader': 'Play of DeBrincat, Crawford among unknowns heading into best-of-5 series vs. Oilers', 'date': ''}
# {'_id': ObjectId('5ee8237bdcec0218ff7323a0'), 'header': 'Reaves signs two-year, $3.5 million contract with Golden Knights', 'subheader': 'Forward could have been unrestricted free agent after season', 'date': ''}
# {'_id': ObjectId('5ee8237bdcec0218ff7323a1'), 'header': '2004 NHL Redraft: Ovechkin, Malkin again top two picks', 'subheader': 'Krejci moves up 59 spots to No. 4; Rinne goes from eighth round to top five', 'date': ''}
# {'_id': ObjectId('5ee8237bdcec0218ff7323a2'), 'header': 'Stanley Cup Playoffs to be best-of-7 following qualifiers', 'subheader': 'Seeding format, round-robin tiebreakers also announced', 'date': ''}
# {'_id': ObjectId('5ee8237bdcec0218ff7323a3'), 'header': 'Greatest Moments of the NHL Season … So Far reaches final four', 'subheader': 'Ayres to face Svechnikov, Rinne against Fleury in fan voting next week', 'date': ''}
# {'_id': ObjectId('5ee8237bdcec0218ff7323a4'), 'header': "'NHL's Who Wore It Best?': Nos. 10-1", 'subheader': 'Howe, Orr, Plante among top vote-getters for his uniform number', 'date': ''}
# {'_id': ObjectId('5ee8237bdcec0218ff7323a5'), 'header': 'Favorite playoff memory: Turco recalls four-OT game with Stars', 'subheader': 'Made 61 saves against Sharks to win eighth-longest game in NHL history', 'date': ''}
# {'_id': ObjectId('5ee8237bdcec0218ff7323a6'), 'header': 'Fantasy forward top 100 rankings for 2020 Stanley Cup', 'subheader': 'NHL.com lists best options at position for 24-team tournament; podcast analysis', 'date': ''}
# {'_id': ObjectId('5ee8237bdcec0218ff7323a7'), 'header': 'NHL teams continue voluntary workouts as part of Phase 2', 'subheader': 'Several have opened facilities in next step of Return to Play Plan', 'date': ''}
# {'_id': ObjectId('5ee8237bdcec0218ff7323a8'), 'header': 'Color of Hockey: NHLCA clinic provides steppingstone for black coaches', 'subheader': 'Weeklong gathering offers opportunities for learning, networking, mentoring', 'date': ''}
# {'_id': ObjectId('5ee8237bdcec0218ff7323a9'), 'header': 'Montreal Dragons league lets LGBTQ+ players be themselves', 'subheader': "Provides fun, safe, competitive atmosphere with 'no prejudice, no judgment'", 'date': ''}
# {'_id': ObjectId('5ee8237bdcec0218ff7323aa'), 'header': 'Ducks honor Class of 2020 with graduation gifts outside Honda Center', 'subheader': 'Team hosts celebration for those whose commencement was postponed due to COVID-19 pandemic', 'date': ''}
# {'_id': ObjectId('5ee8237bdcec0218ff7323ab'), 'header': 'Reaves announces some lofty goals after re-signing with Golden Knights', 'subheader': 'Forward is pumped to stay in Vegas, ready to make up 95-point gap to win scoring title', 'date': ''}
# {'_id': ObjectId('5ee8237bdcec0218ff7323ac'), 'header': 'NHL plans to return with 24 teams competing for Stanley Cup', 'subheader': 'Will begin with best-of-5 series, round-robin games in two hub cities; date not determined', 'date': ''}
# {'_id': ObjectId('5ee8237bdcec0218ff7323ad'), 'header': 'Fantasy pool rankings for 2020 Stanley Cup', 'subheader': 'NHL.com lists top 100 overall players for 24-team tournament; podcast analysis', 'date': ''}
# {'_id': ObjectId('5ee8237bdcec0218ff7323ae'), 'header': 'Six NHL executives part of AHL 2020-21 Return to Play task force', 'subheader': 'Will provide leadership, help identify opportunities for process acceptable to each league', 'date': ''}
# {'_id': ObjectId('5ee8237bdcec0218ff7323af'), 'header': 'McDavid, Rinne, Fleury and more win 2020 NHL Fan Choice Awards', 'subheader': 'There were more than a few tight races, but voting is finished and hockey fans have spoken', 'date': ''}
# {'_id': ObjectId('5ee8237bdcec0218ff7323b0'), 'header': 'Our Vision: Hockey Is Indeed For Everyone', 'subheader': 'We can, will do better, as a League, as a game', 'date': ''}
# {'_id': ObjectId('5ee8237bdcec0218ff7323b1'), 'header': 'Super 16: Top goalies playing in Stanley Cup Qualifiers', 'subheader': 'Rask, Vasilevskiy among best in NHL.com ranking of those returning to play', 'date': ''}
# {'_id': ObjectId('5ee8237bdcec0218ff7323b2'), 'header': "Marner 'amazes me,' Marleau says of former Maple Leafs teammate", 'subheader': 'Forward has tools to be one of top players in NHL, according to Penguins veteran', 'date': ''}
# {'_id': ObjectId('5ee8237bdcec0218ff7323b3'), 'header': 'NHL Fantasy on Ice podcast available now', 'subheader': 'Fantasy pool rankings debate; ceiling of Flyers, Maple Leafs; guest: Alberga', 'date': ''}
# {'_id': ObjectId('5ee8237bdcec0218ff7323b4'), 'header': 'June 15: Bruins win Cup for first time in 39 years', 'subheader': 'Plus: Ducks join NHL; Blackhawks top Lightning for third championship in six seasons', 'date': ''}
# {'_id': ObjectId('5ee82382dcec0218ff7323b5'), 'header': '5 questions for Canadiens in Stanley Cup Qualifiers', 'subheader': 'Play of Price, Domi status among unknowns heading into best-of-5 series vs. Penguins', 'date': ''}
# {'_id': ObjectId('5ee82382dcec0218ff7323b6'), 'header': 'Ovechkin could rejoin Capitals in near future, Reirden says', 'subheader': "Forward has been training in Florida during pause, in a 'really good spot mentally and physically'", 'date': ''}
# ...
# {'_id': ObjectId('5ee823ebdcec0218ff7323e4'), 'header': 'Ducks honor Class of 2020 with graduation gifts outside Honda Center', 'subheader': 'Team hosts celebration for those whose commencement was postponed due to COVID-19 pandemic', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee823ebdcec0218ff7323e5'), 'header': 'Reaves announces some lofty goals after re-signing with Golden Knights', 'subheader': 'Forward is pumped to stay in Vegas, ready to make up 95-point gap to win scoring title', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee823ebdcec0218ff7323e6'), 'header': 'NHL plans to return with 24 teams competing for Stanley Cup', 'subheader': 'Will begin with best-of-5 series, round-robin games in two hub cities; date not determined', 'date': '2020-06-09'}
# {'_id': ObjectId('5ee823ebdcec0218ff7323e7'), 'header': 'Fantasy pool rankings for 2020 Stanley Cup', 'subheader': 'NHL.com lists top 100 overall players for 24-team tournament; podcast analysis', 'date': '2020-06-12'}
# {'_id': ObjectId('5ee823ebdcec0218ff7323e8'), 'header': 'Six NHL executives part of AHL 2020-21 Return to Play task force', 'subheader': 'Will provide leadership, help identify opportunities for process acceptable to each league', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee823ebdcec0218ff7323e9'), 'header': 'McDavid, Rinne, Fleury and more win 2020 NHL Fan Choice Awards', 'subheader': 'There were more than a few tight races, but voting is finished and hockey fans have spoken', 'date': '2020-06-13'}
# {'_id': ObjectId('5ee823ebdcec0218ff7323ea'), 'header': 'Our Vision: Hockey Is Indeed For Everyone', 'subheader': 'We can, will do better, as a League, as a game', 'date': '2020-06-11'}
# {'_id': ObjectId('5ee823ebdcec0218ff7323eb'), 'header': 'Super 16: Top goalies playing in Stanley Cup Qualifiers', 'subheader': 'Rask, Vasilevskiy among best in NHL.com ranking of those returning to play', 'date': '2020-06-11'}
# {'_id': ObjectId('5ee823ebdcec0218ff7323ec'), 'header': "Marner 'amazes me,' Marleau says of former Maple Leafs teammate", 'subheader': 'Forward has tools to be one of top players in NHL, according to Penguins veteran', 'date': '2020-06-13'}
# {'_id': ObjectId('5ee823ebdcec0218ff7323ed'), 'header': 'NHL Fantasy on Ice podcast available now', 'subheader': 'Fantasy pool rankings debate; ceiling of Flyers, Maple Leafs; guest: Alberga', 'date': '2020-06-15'}
# {'_id': ObjectId('5ee823ebdcec0218ff7323ee'), 'header': 'June 15: Bruins win Cup for first time in 39 years', 'subheader': 'Plus: Ducks join NHL; Blackhawks top Lightning for third championship in six seasons', 'date': '2020-06-15'}
# {'_id': ObjectId('5fd94656125fbea545b6a880'), 'header': 'Stolen Gretzky memorabilia recovered, two arrests made', 'subheader': "Sticks, gloves, jerseys worth $500,000 were taken from home of Hall of Famer's father", 'date': '2020-12-15'}
# {'_id': ObjectId('5fd94656125fbea545b6a881'), 'header': 'Inside look at Washington Capitals', 'subheader': 'New coach Laviolette aims to spur veteran core to another Cup title', 'date': '2020-12-15'}
# {'_id': ObjectId('5fd94656125fbea545b6a882'), 'header': "Crawford's new Devils mask is demonic nightmare fuel", 'subheader': "Goalie's helmet features horned skull, flames in terrifying design", 'date': '2020-12-15'}
# {'_id': ObjectId('5fd94656125fbea545b6a883'), 'header': 'Five Questions with Tony Granato', 'subheader': 'Wisconsin coach discusses developing top prospects, ignoring gender in hockey', 'date': '2020-12-15'}
# {'_id': ObjectId('5fd94656125fbea545b6a884'), 'header': '2021 World Junior Championship rosters', 'subheader': 'Kings top NHL again with nine prospects; country, NHL affiliation for all participants', 'date': '2020-12-14'}
# {'_id': ObjectId('5fd94656125fbea545b6a885'), 'header': 'Reverse Retro alternate jerseys for all 31 teams unveiled by NHL, adidas', 'subheader': 'Now available for purchase, will be worn multiple times this season', 'date': '2020-12-01'}
# {'_id': ObjectId('5fd94656125fbea545b6a886'), 'header': 'Three questions facing Washington Capitals', 'subheader': "Lundqvist's role, Ovechkin contract status among concerns", 'date': '2020-12-15'}
# {'_id': ObjectId('5fd94656125fbea545b6a887'), 'header': 'NHL Prospect Watch: Austria, Switzerland, Slovenia', 'subheader': "Peterka impresses Sabres; Red Wings' 2019 first-round pick Zadina set for Channel One Cup", 'date': '2020-12-15'}
# {'_id': ObjectId('5fd94656125fbea545b6a888'), 'header': '#NHLTopPlayers: Nos. 40-31', 'subheader': 'NHL Network reveals best of current crop', 'date': '2020-12-13'}
# {'_id': ObjectId('5fd94656125fbea545b6a889'), 'header': 'Lacroix dies at 72, won Stanley Cup twice as Avalanche GM', 'subheader': 'Made blockbuster trades for Roy, Bourque, Blake; had been player agent', 'date': '2020-12-13'}
# {'_id': ObjectId('5fd94656125fbea545b6a88a'), 'header': 'NHL.com holiday gift guide', 'subheader': "From hoodies to jerseys to collectibles, can't-miss items for hockey fans on your list", 'date': '2020-11-27'}
# {'_id': ObjectId('5fd94656125fbea545b6a88b'), 'header': 'Color of Hockey: Dallas fixture in game now coaching coaches', 'subheader': 'Clarke, son of Jamaican immigrants, plying trade at national level', 'date': '2020-12-14'}
# {'_id': ObjectId('5fd94656125fbea545b6a88c'), 'header': 'Fantasy hockey top 250 player rankings', 'subheader': 'NHL.com lists best overall options for standard leagues; season preview podcasts', 'date': '2020-12-15'}
# {'_id': ObjectId('5fd94656125fbea545b6a88d'), 'header': 'Top prospects for Washington Capitals', 'subheader': 'High-scoring McMichael to refine game in OHL; Fehervary likely to await callup from AHL', 'date': '2020-12-15'}
# {'_id': ObjectId('5fd94656125fbea545b6a88e'), 'header': 'Kings turning page on rebuilding phase, McLellan says: report', 'subheader': "Coach thinks long-term players should be 'excited to hear that'", 'date': '2020-12-12'}
# {'_id': ObjectId('5fd94656125fbea545b6a88f'), 'header': 'NHL Free Agent Tracker', 'subheader': 'Complete list of signings by team, available players', 'date': '2020-12-15'}
# {'_id': ObjectId('5fd94656125fbea545b6a890'), 'header': "Power thinks he's worthy of No. 1 pick in 2021 on NHL Draft Class podcast", 'subheader': 'Latest episode features Michigan defenseman on season, coach on top prospects', 'date': '2020-12-15'}
# {'_id': ObjectId('5fd94656125fbea545b6a891'), 'header': 'Keeper of Stanley Cup NHL toy set from Playmobil still a classic', 'subheader': 'Phil Pritchard, Curator of Hockey Hall of Fame, shares pictures of his action figure', 'date': '2020-12-14'}
# {'_id': ObjectId('5fd94656125fbea545b6a892'), 'header': 'Laing inspired by Travis Roy, takes part in spinal cord injury study', 'subheader': 'Former NWHL player joined trial with support of onetime Boston University player who died in October', 'date': '2020-12-13'}
# {'_id': ObjectId('5fd94656125fbea545b6a893'), 'header': 'Washington Capitals key statistics', 'subheader': 'Vrana could boost goals; Orlov helps drive puck-possession metrics', 'date': '2020-12-15'}
# {'_id': ObjectId('5fd94656125fbea545b6a894'), 'header': '2020-21 NHL Trade Tracker', 'subheader': 'Official deals since Oct. 1, 2020', 'date': '2020-12-11'}
# {'_id': ObjectId('5fd94656125fbea545b6a895'), 'header': 'Holtby issues apology for Canucks mask after First Nations criticism', 'subheader': 'Goalie says he will work with Indigenous artist to create new design', 'date': '2020-12-13'}
# {'_id': ObjectId('5fd94656125fbea545b6a896'), 'header': 'Gretzky rookie card sells for record $1.29 million at auction', 'subheader': 'O-Pee-Chee collectible from 1978-79 season is first to fetch seven figures', 'date': '2020-12-11'}
# {'_id': ObjectId('5fd94656125fbea545b6a897'), 'header': 'Washington Capitals fantasy preview for 2020-21', 'subheader': 'Kuznetsov, Backstrom each in line for bounce-back season; Wilson adds value in hits leagues', 'date': '2020-12-15'}
# {'_id': ObjectId('5fd94656125fbea545b6a898'), 'header': '2021 World Junior Championship schedule', 'subheader': 'Tournament to start Dec. 25, will be played in Edmonton bubble without fans', 'date': '2020-12-14'}
# {'_id': ObjectId('5fd94656125fbea545b6a899'), 'header': 'Coyotes, Make-A-Wish Arizona team up to bring backyard rink to young fan', 'subheader': 'After two heart surgeries, young player received place all his to practice hockey', 'date': '2020-12-13'}
# {'_id': ObjectId('5fd94656125fbea545b6a89a'), 'header': "Canada division probable for '20-21 NHL season, Commissioner Bettman says", 'subheader': 'Start date, number of games yet to be agreed upon', 'date': '2020-12-08'}
# {'_id': ObjectId('5fd94656125fbea545b6a89b'), 'header': "Lapointe says Canadiens 'have no excuses' this season", 'subheader': "Six-time Stanley Cup champion, now cancer-free, bullish on Montreal's playoff chances", 'date': '2020-12-11'}
# {'_id': ObjectId('5fd94656125fbea545b6a89c'), 'header': 'Inside look at Vegas Golden Knights', 'subheader': 'Add defenseman Pietrangelo in bid for Cup after reaching Western Conference Final last season', 'date': '2020-12-14'}
# {'_id': ObjectId('5fd94656125fbea545b6a89d'), 'header': 'Dec. 15: First NHL game played in New York', 'subheader': 'Plus: Chicago Stadium opener; Olympia Stadium finale', 'date': '2020-12-15'}
# {'_id': ObjectId('5fde1f576f0a764ff5d7c04d'), 'header': 'NHL season would start Jan. 13, play 56 games in agreement with NHLPA', 'subheader': 'Tentative deal includes Canada division, needs approval', 'date': '2020-12-18'}
# {'_id': ObjectId('5fde1f576f0a764ff5d7c04e'), 'header': 'MacKinnon says Avalanche may be favorites to win Stanley Cup', 'subheader': 'Hart Trophy finalist helped Colorado reach Western Conference Second Round last season', 'date': '2020-12-18'}
# {'_id': ObjectId('5fde1f576f0a764ff5d7c04f'), 'header': 'Dach named Canada captain for World Juniors', 'subheader': 'Blackhawks center learns he was chosen for role in McDavid video announcement', 'date': '2020-12-18'}
# {'_id': ObjectId('5fde1f576f0a764ff5d7c050'), 'header': "Lundqvist won't play for Capitals this season because of heart condition", 'subheader': 'Goalie signed one-year contract Oct. 9 to share time with Samsonov after bought out by Rangers', 'date': '2020-12-17'}
# {'_id': ObjectId('5fde1f576f0a764ff5d7c051'), 'header': 'Finland all-time WJC starting lineup includes Teravainen, Laine', 'subheader': 'Tikkanen, Numminen, Lehtonen also on team picked by NHL.com', 'date': '2020-12-19'}
# {'_id': ObjectId('5fde1f576f0a764ff5d7c052'), 'header': 'Reverse Retro alternate jerseys for all 31 teams unveiled by NHL, adidas', 'subheader': 'Now available for purchase, will be worn multiple times this season', 'date': '2020-12-01'}
# {'_id': ObjectId('5fde1f576f0a764ff5d7c053'), 'header': 'Super 16: Top NHL forwards', 'subheader': 'McDavid, MacKinnon, Crosby among best in NHL.com rankings', 'date': '2020-12-17'}
# {'_id': ObjectId('5fde1f576f0a764ff5d7c054'), 'header': 'Germany has eight players test positive for COVID-19 at World Juniors', 'subheader': 'Will remain quarantined until Dec. 24; Sweden also in extended isolation', 'date': '2020-12-18'}
# {'_id': ObjectId('5fde1f576f0a764ff5d7c055'), 'header': 'Holtby working with Indigenous artist on new mask for Canucks', 'subheader': 'Goalie apologized after helmet designed by Swedish artist sparked cultural appropriation calls', 'date': '2020-12-18'}
# {'_id': ObjectId('5fde1f576f0a764ff5d7c056'), 'header': 'Fantasy top 10 sleeper candidates for 2020-21', 'subheader': 'NHL.com lists potential steals attainable in late rounds; season preview podcast', 'date': '2020-12-18'}
# {'_id': ObjectId('5fde1f576f0a764ff5d7c057'), 'header': 'NHL.com holiday gift guide', 'subheader': "From hoodies to jerseys to collectibles, can't-miss items for hockey fans on your list", 'date': '2020-11-27'}
# {'_id': ObjectId('5fde1f576f0a764ff5d7c058'), 'header': 'Flames executive Snow adjusting to feeding tube in ALS treatment', 'subheader': 'Assistant GM had surgery this month after setback during clinical trial', 'date': '2020-12-18'}
# {'_id': ObjectId('5fde1f576f0a764ff5d7c059'), 'header': 'Lundqvist heart condition has Capitals facing uncertainty at goalie', 'subheader': '38-year-old out for season, was expected to share time with Samsonov', 'date': '2020-12-17'}
# {'_id': ObjectId('5fde1f576f0a764ff5d7c05a'), 'header': 'Steen retires from NHL after 15 seasons', 'subheader': '36-year-old forward had back injury, won Stanley Cup with Blues in 2019', 'date': '2020-12-17'}
# {'_id': ObjectId('5fde1f576f0a764ff5d7c05b'), 'header': '2021 World Junior Championship schedule', 'subheader': 'Tournament to start Dec. 25, will be played in Edmonton bubble without fans', 'date': '2020-12-14'}
# {'_id': ObjectId('5fde1f576f0a764ff5d7c05c'), 'header': 'NHL Free Agent Tracker', 'subheader': 'Complete list of signings by team, available players', 'date': '2020-12-18'}
# {'_id': ObjectId('5fde1f576f0a764ff5d7c05d'), 'header': 'Sweden all-time WJC starting lineup includes Peter Forsberg, Karlsson', 'subheader': 'Naslund, Filip Forsberg round out first line of team picked by NHL.com', 'date': '2020-12-18'}
# {'_id': ObjectId('5fde1f576f0a764ff5d7c05e'), 'header': 'Duclair agrees to one-year contract with Panthers', 'subheader': 'Free agent forward scored NHL career-high 23 goals last season', 'date': '2020-12-17'}
# {'_id': ObjectId('5fde1f576f0a764ff5d7c05f'), 'header': "Lundqvist's current, former teammates show support on social media", 'subheader': 'Players share well wishes for veteran goalie who revealed heart condition', 'date': '2020-12-17'}
# {'_id': ObjectId('5fde1f576f0a764ff5d7c060'), 'header': 'NHL free agent signings fantasy roundup', 'subheader': 'Fantasy spin: Duclair to Panthers; impact of Pietrangelo, Hall, Krug moves', 'date': '2020-12-18'}
# {'_id': ObjectId('5fde1f576f0a764ff5d7c061'), 'header': '2020-21 NHL Trade Tracker', 'subheader': 'Official deals since Oct. 1, 2020', 'date': '2020-12-11'}
# {'_id': ObjectId('5fde1f576f0a764ff5d7c062'), 'header': "Mailbag: Blue Jackets' needs, rise of analytics in hockey", 'subheader': "NHL.com's Dan Rosen answers weekly questions", 'date': '2020-12-16'}
# {'_id': ObjectId('5fde1f576f0a764ff5d7c063'), 'header': "Marner says new veterans on Maple Leafs can 'keep us in line'", 'subheader': 'Forward hopes additions of Thornton, Simmonds help end series-winning drought', 'date': '2020-12-18'}
# {'_id': ObjectId('5fde1f576f0a764ff5d7c064'), 'header': 'Jagr gets assist in Czech Republic to start 33rd pro season', 'subheader': '48-year-old former NHL forward playing for Kladno', 'date': '2020-12-16'}
# {'_id': ObjectId('5fde1f576f0a764ff5d7c065'), 'header': 'Fantasy hockey top 250 player rankings', 'subheader': 'NHL.com lists best overall options for standard leagues; season preview podcasts', 'date': '2020-12-18'}
# {'_id': ObjectId('5fde1f576f0a764ff5d7c066'), 'header': '2021 World Junior Championship rosters', 'subheader': 'Kings top NHL again with nine prospects; country, NHL affiliation for all participants', 'date': '2020-12-14'}
# {'_id': ObjectId('5fde1f576f0a764ff5d7c067'), 'header': "Pacioretty says Golden Knights trade rumors 'lightweight stuff': report", 'subheader': 'Forward has three seasons remaining on four-year, $28 million contract', 'date': '2020-12-18'}
# {'_id': ObjectId('5fde1f576f0a764ff5d7c068'), 'header': 'Stalock could miss start of training camp for Wild with upper-body injury', 'subheader': 'Recovery time for goalie undetermined, Hammond signed to contract', 'date': '2020-12-18'}
# {'_id': ObjectId('5fde1f576f0a764ff5d7c069'), 'header': 'Fantasy hockey top 25 goalie rankings', 'subheader': 'Samsonov among 10 best options with Capitals; Kahkonen worth look from Wild', 'date': '2020-12-17'}
# {'_id': ObjectId('5fde1f576f0a764ff5d7c06a'), 'header': 'Dec. 19: NHL plays first games', 'subheader': 'Plus: Gretzky fastest to 1,000 points; Bourque third defenseman to score 300 goals', 'date': '2020-12-19'}
